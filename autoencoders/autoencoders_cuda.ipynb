# %%
import sys

sys.path.append('../')

# %%
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

from config.regressors import *
from config.models import *
from config.loss_functions import *
from config.transformers import *
from config.validation import *
from config.dann import *

# %%
class AutoEncoder(nn.Module):
    def __init__(self, latent_dim):
        super().__init__()
        
        # Encoder: [3 → 64 → 32 → 16 → latent_dim]
        self.encoder = nn.Sequential(
            nn.Linear(3, 16),
            nn.SELU(),
            nn.Linear(16, 8),
            nn.SELU(),
            nn.Linear(8, 4),
            nn.SELU(),
            nn.Linear(4, latent_dim)  # No activation
        )
        
        # Decoder: [latent_dim → 16 → 32 → 64 → 3]
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 4),
            nn.SELU(),
            nn.Linear(4, 8),
            nn.SELU(),
            nn.Linear(8, 16),
            nn.SELU(),
            nn.Linear(16, 3)  # No activation
        )
        
        self._init_weights()
    
    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                # LeCun normal initialization for SELU
                nn.init.normal_(m.weight, 0, std=1. / np.sqrt(m.in_features))
                if m.bias is not None:
                    nn.init.zeros_(m.bias)
    
    def forward(self, x):
        return self.decoder(self.encoder(x))

# %%
def trainer(bone, latent_dim):
    # ----------------------------
    # 1. Configuration
    # ----------------------------
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    print(f"Using device: {device}")

    # Hyperparameters
    batch_size     = 4096
    learning_rate  = 1e-3
    weight_decay   = 1e-4
    max_epochs     = 100
    patience       = 20
    num_workers    = 4  # >0 for parallel loading

    # ----------------------------
    # 2. Prepare Data (CPU‑only)
    # ----------------------------
    # Assume Y is your NumPy array of shape [N, 3*B]
    PATH = r'C:\Users\gianm\Documents\Uni\Big Data\F422\project\data\\'
    Y = np.load(PATH + 'Y_all.npy')
    Y_bone = Y[:, bone*3:(bone+1)*3]
    Y_bone = Y[:, bone*3:(bone+1)*3]

    Yb_cpu   = torch.as_tensor(Y_bone, dtype=torch.float32)  # stays on CPU

    dataset      = TensorDataset(Yb_cpu, Yb_cpu)
    train_loader = DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        persistent_workers=True
    )
    val_loader   = DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        persistent_workers=True
    )

    # instantiate with your chosen latent dimension
    model = AutoEncoder(latent_dim).to(device)

    # ----------------------------
    # 4. Loss & Optimizer
    # ----------------------------
    criterion = nn.MSELoss()
    optimizer = optim.Adam(
        model.parameters(),
        lr=learning_rate,
        weight_decay=weight_decay
    )

    # ----------------------------
    # 5. Training Loop w/ Early Stopping
    # ----------------------------
    best_val_loss     = float('inf')
    epochs_no_improve = 0

    for epoch in range(1, max_epochs+1):
        # —— Training —— 
        model.train()
        running_loss = 0.0

        for xb_cpu, yb_cpu in train_loader:
            # move batch to MPS (or CUDA) on-the-fly
            xb = xb_cpu.to(device, non_blocking=True)
            yb = yb_cpu.to(device, non_blocking=True)

            optimizer.zero_grad()
            preds = model(xb)              
            loss  = criterion(preds, yb)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        avg_train_loss = running_loss / len(train_loader)

        # —— Validation ——
        model.eval()
        running_val = 0.0
        with torch.no_grad():
            for xb_cpu, yb_cpu in val_loader:
                xb = xb_cpu.to(device, non_blocking=True)
                yb = yb_cpu.to(device, non_blocking=True)
                running_val += criterion(model(xb), yb).item()
        avg_val_loss = running_val / len(val_loader)

        print(f"Epoch {epoch:02d}: Train MSE = {avg_train_loss:.6f} | Val MSE = {avg_val_loss:.6f}")

        # —— Early Stopping ——
        if avg_val_loss < best_val_loss:
            best_val_loss     = avg_val_loss
            epochs_no_improve = 0
            torch.save(model.state_dict(), f"best_models_cuda/best_model_bone{bone}.pth")
            print("  → New best model saved")
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print("Early stopping triggered")
                break

# %%
# PATH = r'C:\Users\gianm\Documents\Uni\Big Data\F422\project\data\\'

# DATASET = 'guided'
# Y = np.load(PATH + f'{DATASET}/{DATASET}_dataset_Y.npy')
# Y = Y.transpose(0, 2, 1).reshape(-1, Y.shape[1])

# DATASET = 'freemoves'
# YY = np.load(PATH + f'{DATASET}/{DATASET}_dataset_Y.npy')
# YY = YY.transpose(0, 2, 1).reshape(-1, YY.shape[1])

# Y_all = np.vstack([Y, YY])

# np.save(PATH + 'Y_all.npy', Y_all)

# latent_dims = {
#         0: 1, 1: 1, 2: 1,
#         3: 1, 4: 2, 5: 1,
#         6: 1, 7: 2, 8: 1,
#         9: 1, 10: 2, 11: 1,
#         12: 1, 13: 1, 14: 2,
#         15: 1, 16: 1,}

# for bone in range(17):
#     trainer(bone, latent_dims[bone])
# Out:
# Using device: cuda
# Epoch 01: Train MSE = 201.669550 | Val MSE = 45.854745
#   → New best model saved
# Epoch 02: Train MSE = 44.262359 | Val MSE = 42.299581
#   → New best model saved
# Epoch 03: Train MSE = 39.035336 | Val MSE = 34.545258
#   → New best model saved
# Epoch 04: Train MSE = 23.843714 | Val MSE = 9.010370
#   → New best model saved
# Epoch 05: Train MSE = 2.457708 | Val MSE = 0.443657
#   → New best model saved
# Epoch 06: Train MSE = 0.300545 | Val MSE = 0.237245
#   → New best model saved
# Epoch 07: Train MSE = 0.228174 | Val MSE = 0.223350
#   → New best model saved
# Epoch 08: Train MSE = 0.224349 | Val MSE = 0.224297
# Epoch 09: Train MSE = 0.224494 | Val MSE = 0.222168
#   → New best model saved
# Epoch 10: Train MSE = 0.224661 | Val MSE = 0.223163
# Epoch 11: Train MSE = 0.224339 | Val MSE = 0.236498
# Epoch 12: Train MSE = 0.224620 | Val MSE = 0.224000
# Epoch 13: Train MSE = 0.224116 | Val MSE = 0.219629
#   → New best model saved
# Epoch 14: Train MSE = 0.212893 | Val MSE = 0.200944
#   → New best model saved
# Epoch 15: Train MSE = 0.194342 | Val MSE = 0.183289
#   → New best model saved
# Epoch 16: Train MSE = 0.163855 | Val MSE = 0.147087
#   → New best model saved
# Epoch 17: Train MSE = 0.116184 | Val MSE = 0.090614
#   → New best model saved
# Epoch 18: Train MSE = 0.078964 | Val MSE = 0.068528
#   → New best model saved
# Epoch 19: Train MSE = 0.065369 | Val MSE = 0.060677
#   → New best model saved
# Epoch 20: Train MSE = 0.062640 | Val MSE = 0.059214
#   → New best model saved
# Epoch 21: Train MSE = 0.061389 | Val MSE = 0.065364
# Epoch 22: Train MSE = 0.061240 | Val MSE = 0.058429
#   → New best model saved
# Epoch 23: Train MSE = 0.060897 | Val MSE = 0.060117
# Epoch 24: Train MSE = 0.060660 | Val MSE = 0.059083
# Epoch 25: Train MSE = 0.060303 | Val MSE = 0.060914
# Epoch 26: Train MSE = 0.060232 | Val MSE = 0.066817
# Epoch 27: Train MSE = 0.059514 | Val MSE = 0.059986
# Epoch 28: Train MSE = 0.059146 | Val MSE = 0.057989
#   → New best model saved
# Epoch 29: Train MSE = 0.057857 | Val MSE = 0.055434
#   → New best model saved
# Epoch 30: Train MSE = 0.057112 | Val MSE = 0.071308
# Epoch 31: Train MSE = 0.055467 | Val MSE = 0.053243
#   → New best model saved
# Epoch 32: Train MSE = 0.054168 | Val MSE = 0.052865
#   → New best model saved
# Epoch 33: Train MSE = 0.051999 | Val MSE = 0.048661
#   → New best model saved
# Epoch 34: Train MSE = 0.048397 | Val MSE = 0.044568
#   → New best model saved
# Epoch 35: Train MSE = 0.044207 | Val MSE = 0.042021
#   → New best model saved
# Epoch 36: Train MSE = 0.040095 | Val MSE = 0.037117
#   → New best model saved
# Epoch 37: Train MSE = 0.037503 | Val MSE = 0.034360
#   → New best model saved
# Epoch 38: Train MSE = 0.036223 | Val MSE = 0.039059
# Epoch 39: Train MSE = 0.034462 | Val MSE = 0.033382
#   → New best model saved
# Epoch 40: Train MSE = 0.034612 | Val MSE = 0.035349
# Epoch 41: Train MSE = 0.033226 | Val MSE = 0.034522
# Epoch 42: Train MSE = 0.033446 | Val MSE = 0.030752
#   → New best model saved
# Epoch 43: Train MSE = 0.032627 | Val MSE = 0.030653
#   → New best model saved
# Epoch 44: Train MSE = 0.032634 | Val MSE = 0.030950
# Epoch 45: Train MSE = 0.032328 | Val MSE = 0.030188
#   → New best model saved
# Epoch 46: Train MSE = 0.032123 | Val MSE = 0.037033
# Epoch 47: Train MSE = 0.031946 | Val MSE = 0.038145
# Epoch 48: Train MSE = 0.031787 | Val MSE = 0.038168
# Epoch 49: Train MSE = 0.031668 | Val MSE = 0.037815
# Epoch 50: Train MSE = 0.031511 | Val MSE = 0.034881
# Epoch 51: Train MSE = 0.031735 | Val MSE = 0.036415
# Epoch 52: Train MSE = 0.031401 | Val MSE = 0.030305
# Epoch 53: Train MSE = 0.030967 | Val MSE = 0.033852
# Epoch 54: Train MSE = 0.030960 | Val MSE = 0.030168
#   → New best model saved
# Epoch 55: Train MSE = 0.030928 | Val MSE = 0.028572
#   → New best model saved
# Epoch 56: Train MSE = 0.030699 | Val MSE = 0.032798
# Epoch 57: Train MSE = 0.030678 | Val MSE = 0.031390
# Epoch 58: Train MSE = 0.030345 | Val MSE = 0.035646
# Epoch 59: Train MSE = 0.030542 | Val MSE = 0.028144
#   → New best model saved
# Epoch 60: Train MSE = 0.030246 | Val MSE = 0.030447
# Epoch 61: Train MSE = 0.030056 | Val MSE = 0.030711
# Epoch 62: Train MSE = 0.030156 | Val MSE = 0.029684
# Epoch 63: Train MSE = 0.029969 | Val MSE = 0.028610
# Epoch 64: Train MSE = 0.030049 | Val MSE = 0.029033
# Epoch 65: Train MSE = 0.029535 | Val MSE = 0.028203
# Epoch 66: Train MSE = 0.029939 | Val MSE = 0.034552
# Epoch 67: Train MSE = 0.029647 | Val MSE = 0.027541
#   → New best model saved
# Epoch 68: Train MSE = 0.029626 | Val MSE = 0.028956
# Epoch 69: Train MSE = 0.029558 | Val MSE = 0.027839
# Epoch 70: Train MSE = 0.029418 | Val MSE = 0.029200
# Epoch 71: Train MSE = 0.029271 | Val MSE = 0.030868
# Epoch 72: Train MSE = 0.029213 | Val MSE = 0.028866
# Epoch 73: Train MSE = 0.029727 | Val MSE = 0.035674
# Epoch 74: Train MSE = 0.029221 | Val MSE = 0.029613
# Epoch 75: Train MSE = 0.029000 | Val MSE = 0.027127
#   → New best model saved
# Epoch 76: Train MSE = 0.029171 | Val MSE = 0.027949
# Epoch 77: Train MSE = 0.028908 | Val MSE = 0.028679
# Epoch 78: Train MSE = 0.028986 | Val MSE = 0.026772
#   → New best model saved
# Epoch 79: Train MSE = 0.028806 | Val MSE = 0.026695
#   → New best model saved
# Epoch 80: Train MSE = 0.028503 | Val MSE = 0.032166
# Epoch 81: Train MSE = 0.028711 | Val MSE = 0.027431
# Epoch 82: Train MSE = 0.028590 | Val MSE = 0.026925
# Epoch 83: Train MSE = 0.028385 | Val MSE = 0.026371
#   → New best model saved
# Epoch 84: Train MSE = 0.028553 | Val MSE = 0.028606
# Epoch 85: Train MSE = 0.028393 | Val MSE = 0.029924
# Epoch 86: Train MSE = 0.028259 | Val MSE = 0.027763
# Epoch 87: Train MSE = 0.028159 | Val MSE = 0.026181
#   → New best model saved
# Epoch 88: Train MSE = 0.028193 | Val MSE = 0.026144
#   → New best model saved
# Epoch 89: Train MSE = 0.028279 | Val MSE = 0.029240
# Epoch 90: Train MSE = 0.027929 | Val MSE = 0.026356
# Epoch 91: Train MSE = 0.028105 | Val MSE = 0.029281
# Epoch 92: Train MSE = 0.028046 | Val MSE = 0.027854
# Epoch 93: Train MSE = 0.028010 | Val MSE = 0.027171
# Epoch 94: Train MSE = 0.027743 | Val MSE = 0.026450
# Epoch 95: Train MSE = 0.027975 | Val MSE = 0.028686
# Epoch 96: Train MSE = 0.027741 | Val MSE = 0.029255
# Epoch 97: Train MSE = 0.027659 | Val MSE = 0.026380
# Epoch 98: Train MSE = 0.027880 | Val MSE = 0.029635
# Epoch 99: Train MSE = 0.027683 | Val MSE = 0.028705
# Epoch 100: Train MSE = 0.027485 | Val MSE = 0.029172
# Using device: cuda
# Epoch 01: Train MSE = 63.066778 | Val MSE = 35.205069
#   → New best model saved
# Epoch 02: Train MSE = 31.377638 | Val MSE = 21.718739
#   → New best model saved
# Epoch 03: Train MSE = 8.972460 | Val MSE = 1.872172
#   → New best model saved
# Epoch 04: Train MSE = 0.507821 | Val MSE = 0.111460
#   → New best model saved
# Epoch 05: Train MSE = 0.105100 | Val MSE = 0.102133
#   → New best model saved
# Epoch 06: Train MSE = 0.100746 | Val MSE = 0.097540
#   → New best model saved
# Epoch 07: Train MSE = 0.086268 | Val MSE = 0.071054
#   → New best model saved
# Epoch 08: Train MSE = 0.060507 | Val MSE = 0.052545
#   → New best model saved
# Epoch 09: Train MSE = 0.049303 | Val MSE = 0.045039
#   → New best model saved
# Epoch 10: Train MSE = 0.043216 | Val MSE = 0.039755
#   → New best model saved
# Epoch 11: Train MSE = 0.038730 | Val MSE = 0.037772
#   → New best model saved
# Epoch 12: Train MSE = 0.035205 | Val MSE = 0.032197
#   → New best model saved
# Epoch 13: Train MSE = 0.032011 | Val MSE = 0.029446
#   → New best model saved
# Epoch 14: Train MSE = 0.029374 | Val MSE = 0.026632
#   → New best model saved
# Epoch 15: Train MSE = 0.026018 | Val MSE = 0.022660
#   → New best model saved
# Epoch 16: Train MSE = 0.022001 | Val MSE = 0.023316
# Epoch 17: Train MSE = 0.019070 | Val MSE = 0.016565
#   → New best model saved
# Epoch 18: Train MSE = 0.016871 | Val MSE = 0.014177
#   → New best model saved
# Epoch 19: Train MSE = 0.015026 | Val MSE = 0.012629
#   → New best model saved
# Epoch 20: Train MSE = 0.013892 | Val MSE = 0.014757
# Epoch 21: Train MSE = 0.013256 | Val MSE = 0.011173
#   → New best model saved
# Epoch 22: Train MSE = 0.012777 | Val MSE = 0.010618
#   → New best model saved
# Epoch 23: Train MSE = 0.012220 | Val MSE = 0.010785
# Epoch 24: Train MSE = 0.011893 | Val MSE = 0.017277
# Epoch 25: Train MSE = 0.011811 | Val MSE = 0.010118
#   → New best model saved
# Epoch 26: Train MSE = 0.011745 | Val MSE = 0.013401
# Epoch 27: Train MSE = 0.011312 | Val MSE = 0.009785
#   → New best model saved
# Epoch 28: Train MSE = 0.011132 | Val MSE = 0.015402
# Epoch 29: Train MSE = 0.011061 | Val MSE = 0.010893
# Epoch 30: Train MSE = 0.010924 | Val MSE = 0.010123
# Epoch 31: Train MSE = 0.010241 | Val MSE = 0.008115
#   → New best model saved
# Epoch 32: Train MSE = 0.009944 | Val MSE = 0.008238
# Epoch 33: Train MSE = 0.009704 | Val MSE = 0.008885
# Epoch 34: Train MSE = 0.009461 | Val MSE = 0.007298
#   → New best model saved
# Epoch 35: Train MSE = 0.009169 | Val MSE = 0.007226
#   → New best model saved
# Epoch 36: Train MSE = 0.009137 | Val MSE = 0.012443
# Epoch 37: Train MSE = 0.009203 | Val MSE = 0.008538
# Epoch 38: Train MSE = 0.008795 | Val MSE = 0.007393
# Epoch 39: Train MSE = 0.008799 | Val MSE = 0.008412
# Epoch 40: Train MSE = 0.008916 | Val MSE = 0.013088
# Epoch 41: Train MSE = 0.008488 | Val MSE = 0.006722
#   → New best model saved
# Epoch 42: Train MSE = 0.008539 | Val MSE = 0.006672
#   → New best model saved
# Epoch 43: Train MSE = 0.008623 | Val MSE = 0.009331
# Epoch 44: Train MSE = 0.008344 | Val MSE = 0.011883
# Epoch 45: Train MSE = 0.008503 | Val MSE = 0.006669
#   → New best model saved
# Epoch 46: Train MSE = 0.008243 | Val MSE = 0.008436
# Epoch 47: Train MSE = 0.008343 | Val MSE = 0.006166
#   → New best model saved
# Epoch 48: Train MSE = 0.008147 | Val MSE = 0.006261
# Epoch 49: Train MSE = 0.008063 | Val MSE = 0.006029
#   → New best model saved
# Epoch 50: Train MSE = 0.008274 | Val MSE = 0.006010
#   → New best model saved
# Epoch 51: Train MSE = 0.008242 | Val MSE = 0.005955
#   → New best model saved
# Epoch 52: Train MSE = 0.007830 | Val MSE = 0.007368
# Epoch 53: Train MSE = 0.008087 | Val MSE = 0.005903
#   → New best model saved
# Epoch 54: Train MSE = 0.007858 | Val MSE = 0.008754
# Epoch 55: Train MSE = 0.007941 | Val MSE = 0.006419
# Epoch 56: Train MSE = 0.008108 | Val MSE = 0.008694
# Epoch 57: Train MSE = 0.007480 | Val MSE = 0.006757
# Epoch 58: Train MSE = 0.007888 | Val MSE = 0.006316
# Epoch 59: Train MSE = 0.007893 | Val MSE = 0.006561
# Epoch 60: Train MSE = 0.007510 | Val MSE = 0.005658
#   → New best model saved
# Epoch 61: Train MSE = 0.007672 | Val MSE = 0.018380
# Epoch 62: Train MSE = 0.007880 | Val MSE = 0.005579
#   → New best model saved
# Epoch 63: Train MSE = 0.007596 | Val MSE = 0.005531
#   → New best model saved
# Epoch 64: Train MSE = 0.007500 | Val MSE = 0.008254
# Epoch 65: Train MSE = 0.007507 | Val MSE = 0.005640
# Epoch 66: Train MSE = 0.007525 | Val MSE = 0.007998
# Epoch 67: Train MSE = 0.007545 | Val MSE = 0.005759
# Epoch 68: Train MSE = 0.007598 | Val MSE = 0.005513
#   → New best model saved
# Epoch 69: Train MSE = 0.007389 | Val MSE = 0.010584
# Epoch 70: Train MSE = 0.007366 | Val MSE = 0.005751
# Epoch 71: Train MSE = 0.007363 | Val MSE = 0.028150
# Epoch 72: Train MSE = 0.007466 | Val MSE = 0.006121
# Epoch 73: Train MSE = 0.007352 | Val MSE = 0.008235
# Epoch 74: Train MSE = 0.007685 | Val MSE = 0.005339
#   → New best model saved
# Epoch 75: Train MSE = 0.007200 | Val MSE = 0.005574
# Epoch 76: Train MSE = 0.007225 | Val MSE = 0.005286
#   → New best model saved
# Epoch 77: Train MSE = 0.007213 | Val MSE = 0.005433
# Epoch 78: Train MSE = 0.007557 | Val MSE = 0.006156
# Epoch 79: Train MSE = 0.007022 | Val MSE = 0.033501
# Epoch 80: Train MSE = 0.007158 | Val MSE = 0.005637
# Epoch 81: Train MSE = 0.007199 | Val MSE = 0.006151
# Epoch 82: Train MSE = 0.007244 | Val MSE = 0.006666
# Epoch 83: Train MSE = 0.007247 | Val MSE = 0.005203
#   → New best model saved
# Epoch 84: Train MSE = 0.007145 | Val MSE = 0.005730
# Epoch 85: Train MSE = 0.006988 | Val MSE = 0.005244
# Epoch 86: Train MSE = 0.007040 | Val MSE = 0.005228
# Epoch 87: Train MSE = 0.007359 | Val MSE = 0.005309
# Epoch 88: Train MSE = 0.006852 | Val MSE = 0.006070
# Epoch 89: Train MSE = 0.007127 | Val MSE = 0.005964
# Epoch 90: Train MSE = 0.006809 | Val MSE = 0.007441
# Epoch 91: Train MSE = 0.007197 | Val MSE = 0.005101
#   → New best model saved
# Epoch 92: Train MSE = 0.006921 | Val MSE = 0.008153
# Epoch 93: Train MSE = 0.007047 | Val MSE = 0.004997
#   → New best model saved
# Epoch 94: Train MSE = 0.006809 | Val MSE = 0.006915
# Epoch 95: Train MSE = 0.007043 | Val MSE = 0.010654
# Epoch 96: Train MSE = 0.006899 | Val MSE = 0.005066
# Epoch 97: Train MSE = 0.006792 | Val MSE = 0.005671
# Epoch 98: Train MSE = 0.006967 | Val MSE = 0.005111
# Epoch 99: Train MSE = 0.006823 | Val MSE = 0.005035
# Epoch 100: Train MSE = 0.006871 | Val MSE = 0.005190
# Using device: cuda
# Epoch 01: Train MSE = 20.712099 | Val MSE = 1.417394
#   → New best model saved
# Epoch 02: Train MSE = 0.396828 | Val MSE = 0.194423
#   → New best model saved
# Epoch 03: Train MSE = 0.129471 | Val MSE = 0.086064
#   → New best model saved
# Epoch 04: Train MSE = 0.064351 | Val MSE = 0.046584
#   → New best model saved
# Epoch 05: Train MSE = 0.034180 | Val MSE = 0.023478
#   → New best model saved
# Epoch 06: Train MSE = 0.016731 | Val MSE = 0.011506
#   → New best model saved
# Epoch 07: Train MSE = 0.008525 | Val MSE = 0.006109
#   → New best model saved
# Epoch 08: Train MSE = 0.004936 | Val MSE = 0.003849
#   → New best model saved
# Epoch 09: Train MSE = 0.003714 | Val MSE = 0.004156
# Epoch 10: Train MSE = 0.003494 | Val MSE = 0.003358
#   → New best model saved
# Epoch 11: Train MSE = 0.003350 | Val MSE = 0.002899
#   → New best model saved
# Epoch 12: Train MSE = 0.003318 | Val MSE = 0.005323
# Epoch 13: Train MSE = 0.003216 | Val MSE = 0.002839
#   → New best model saved
# Epoch 14: Train MSE = 0.003133 | Val MSE = 0.002713
#   → New best model saved
# Epoch 15: Train MSE = 0.003073 | Val MSE = 0.002364
#   → New best model saved
# Epoch 16: Train MSE = 0.002940 | Val MSE = 0.002673
# Epoch 17: Train MSE = 0.002832 | Val MSE = 0.003490
# Epoch 18: Train MSE = 0.002534 | Val MSE = 0.002712
# Epoch 19: Train MSE = 0.002431 | Val MSE = 0.001756
#   → New best model saved
# Epoch 20: Train MSE = 0.001993 | Val MSE = 0.001442
#   → New best model saved
# Epoch 21: Train MSE = 0.001803 | Val MSE = 0.001662
# Epoch 22: Train MSE = 0.001632 | Val MSE = 0.001459
# Epoch 23: Train MSE = 0.001463 | Val MSE = 0.001277
#   → New best model saved
# Epoch 24: Train MSE = 0.001260 | Val MSE = 0.006134
# Epoch 25: Train MSE = 0.001235 | Val MSE = 0.000741
#   → New best model saved
# Epoch 26: Train MSE = 0.001106 | Val MSE = 0.004965
# Epoch 27: Train MSE = 0.001012 | Val MSE = 0.001017
# Epoch 28: Train MSE = 0.001031 | Val MSE = 0.000449
#   → New best model saved
# Epoch 29: Train MSE = 0.001037 | Val MSE = 0.000460
# Epoch 30: Train MSE = 0.000915 | Val MSE = 0.000524
# Epoch 31: Train MSE = 0.001020 | Val MSE = 0.000457
# Epoch 32: Train MSE = 0.000946 | Val MSE = 0.000437
#   → New best model saved
# Epoch 33: Train MSE = 0.001010 | Val MSE = 0.001449
# Epoch 34: Train MSE = 0.000853 | Val MSE = 0.001328
# Epoch 35: Train MSE = 0.000872 | Val MSE = 0.000437
# Epoch 36: Train MSE = 0.000906 | Val MSE = 0.001051
# Epoch 37: Train MSE = 0.000916 | Val MSE = 0.000427
#   → New best model saved
# Epoch 38: Train MSE = 0.000834 | Val MSE = 0.000408
#   → New best model saved
# Epoch 39: Train MSE = 0.000867 | Val MSE = 0.000405
#   → New best model saved
# Epoch 40: Train MSE = 0.000869 | Val MSE = 0.000401
#   → New best model saved
# Epoch 41: Train MSE = 0.000865 | Val MSE = 0.000385
#   → New best model saved
# Epoch 42: Train MSE = 0.000822 | Val MSE = 0.001012
# Epoch 43: Train MSE = 0.000798 | Val MSE = 0.000382
#   → New best model saved
# Epoch 44: Train MSE = 0.000822 | Val MSE = 0.000432
# Epoch 45: Train MSE = 0.000792 | Val MSE = 0.000372
#   → New best model saved
# Epoch 46: Train MSE = 0.000812 | Val MSE = 0.002933
# Epoch 47: Train MSE = 0.000755 | Val MSE = 0.001142
# Epoch 48: Train MSE = 0.000817 | Val MSE = 0.000559
# Epoch 49: Train MSE = 0.000736 | Val MSE = 0.000505
# Epoch 50: Train MSE = 0.000741 | Val MSE = 0.000353
#   → New best model saved
# Epoch 51: Train MSE = 0.000747 | Val MSE = 0.000470
# Epoch 52: Train MSE = 0.000723 | Val MSE = 0.000441
# Epoch 53: Train MSE = 0.000769 | Val MSE = 0.000425
# Epoch 54: Train MSE = 0.000699 | Val MSE = 0.000375
# Epoch 55: Train MSE = 0.000785 | Val MSE = 0.001393
# Epoch 56: Train MSE = 0.000705 | Val MSE = 0.000475
# Epoch 57: Train MSE = 0.000710 | Val MSE = 0.000488
# Epoch 58: Train MSE = 0.000719 | Val MSE = 0.000675
# Epoch 59: Train MSE = 0.000724 | Val MSE = 0.000376
# Epoch 60: Train MSE = 0.000710 | Val MSE = 0.003239
# Epoch 61: Train MSE = 0.000737 | Val MSE = 0.000355
# Epoch 62: Train MSE = 0.000675 | Val MSE = 0.000570
# Epoch 63: Train MSE = 0.000717 | Val MSE = 0.000368
# Epoch 64: Train MSE = 0.000706 | Val MSE = 0.001373
# Epoch 65: Train MSE = 0.000677 | Val MSE = 0.000433
# Epoch 66: Train MSE = 0.000731 | Val MSE = 0.001771
# Epoch 67: Train MSE = 0.000666 | Val MSE = 0.000354
# Epoch 68: Train MSE = 0.000682 | Val MSE = 0.000654
# Epoch 69: Train MSE = 0.000713 | Val MSE = 0.000344
#   → New best model saved
# Epoch 70: Train MSE = 0.000639 | Val MSE = 0.000352
# Epoch 71: Train MSE = 0.000702 | Val MSE = 0.002116
# Epoch 72: Train MSE = 0.000672 | Val MSE = 0.000367
# Epoch 73: Train MSE = 0.000654 | Val MSE = 0.000341
#   → New best model saved
# Epoch 74: Train MSE = 0.000684 | Val MSE = 0.000336
#   → New best model saved
# Epoch 75: Train MSE = 0.000670 | Val MSE = 0.000338
# Epoch 76: Train MSE = 0.000654 | Val MSE = 0.000480
# Epoch 77: Train MSE = 0.000661 | Val MSE = 0.000474
# Epoch 78: Train MSE = 0.000651 | Val MSE = 0.000343
# Epoch 79: Train MSE = 0.000662 | Val MSE = 0.004695
# Epoch 80: Train MSE = 0.000637 | Val MSE = 0.000344
# Epoch 81: Train MSE = 0.000663 | Val MSE = 0.000330
#   → New best model saved
# Epoch 82: Train MSE = 0.000653 | Val MSE = 0.000429
# Epoch 83: Train MSE = 0.000663 | Val MSE = 0.000328
#   → New best model saved
# Epoch 84: Train MSE = 0.000606 | Val MSE = 0.000321
#   → New best model saved
# Epoch 85: Train MSE = 0.000623 | Val MSE = 0.000350
# Epoch 86: Train MSE = 0.000639 | Val MSE = 0.000327
# Epoch 87: Train MSE = 0.000618 | Val MSE = 0.000582
# Epoch 88: Train MSE = 0.000659 | Val MSE = 0.000591
# Epoch 89: Train MSE = 0.000608 | Val MSE = 0.000324
# Epoch 90: Train MSE = 0.000647 | Val MSE = 0.004434
# Epoch 91: Train MSE = 0.000598 | Val MSE = 0.000452
# Epoch 92: Train MSE = 0.000633 | Val MSE = 0.000369
# Epoch 93: Train MSE = 0.000611 | Val MSE = 0.000308
#   → New best model saved
# Epoch 94: Train MSE = 0.000601 | Val MSE = 0.000493
# Epoch 95: Train MSE = 0.000617 | Val MSE = 0.000323
# Epoch 96: Train MSE = 0.000586 | Val MSE = 0.000416
# Epoch 97: Train MSE = 0.000605 | Val MSE = 0.001183
# Epoch 98: Train MSE = 0.000608 | Val MSE = 0.000301
#   → New best model saved
# Epoch 99: Train MSE = 0.000572 | Val MSE = 0.000295
#   → New best model saved
# Epoch 100: Train MSE = 0.000591 | Val MSE = 0.000672
# Using device: cuda
# Epoch 01: Train MSE = 22.355100 | Val MSE = 0.305455
#   → New best model saved
# Epoch 02: Train MSE = 0.051181 | Val MSE = 0.012095
#   → New best model saved
# Epoch 03: Train MSE = 0.010165 | Val MSE = 0.008425
#   → New best model saved
# Epoch 04: Train MSE = 0.008016 | Val MSE = 0.006790
#   → New best model saved
# Epoch 05: Train MSE = 0.006880 | Val MSE = 0.007227
# Epoch 06: Train MSE = 0.005990 | Val MSE = 0.005364
#   → New best model saved
# Epoch 07: Train MSE = 0.005247 | Val MSE = 0.003980
#   → New best model saved
# Epoch 08: Train MSE = 0.004713 | Val MSE = 0.003425
#   → New best model saved
# Epoch 09: Train MSE = 0.004131 | Val MSE = 0.004814
# Epoch 10: Train MSE = 0.003774 | Val MSE = 0.003016
#   → New best model saved
# Epoch 11: Train MSE = 0.003426 | Val MSE = 0.002561
#   → New best model saved
# Epoch 12: Train MSE = 0.003263 | Val MSE = 0.002235
#   → New best model saved
# Epoch 13: Train MSE = 0.003032 | Val MSE = 0.002229
#   → New best model saved
# Epoch 14: Train MSE = 0.002912 | Val MSE = 0.002424
# Epoch 15: Train MSE = 0.002505 | Val MSE = 0.001965
#   → New best model saved
# Epoch 16: Train MSE = 0.002418 | Val MSE = 0.002924
# Epoch 17: Train MSE = 0.002356 | Val MSE = 0.001593
#   → New best model saved
# Epoch 18: Train MSE = 0.002207 | Val MSE = 0.001606
# Epoch 19: Train MSE = 0.002075 | Val MSE = 0.001441
#   → New best model saved
# Epoch 20: Train MSE = 0.001959 | Val MSE = 0.001649
# Epoch 21: Train MSE = 0.001946 | Val MSE = 0.002096
# Epoch 22: Train MSE = 0.001898 | Val MSE = 0.001281
#   → New best model saved
# Epoch 23: Train MSE = 0.001724 | Val MSE = 0.001268
#   → New best model saved
# Epoch 24: Train MSE = 0.001692 | Val MSE = 0.001192
#   → New best model saved
# Epoch 25: Train MSE = 0.001664 | Val MSE = 0.001804
# Epoch 26: Train MSE = 0.001561 | Val MSE = 0.001069
#   → New best model saved
# Epoch 27: Train MSE = 0.001602 | Val MSE = 0.001420
# Epoch 28: Train MSE = 0.001411 | Val MSE = 0.001063
#   → New best model saved
# Epoch 29: Train MSE = 0.001470 | Val MSE = 0.001567
# Epoch 30: Train MSE = 0.001374 | Val MSE = 0.000931
#   → New best model saved
# Epoch 31: Train MSE = 0.001408 | Val MSE = 0.001191
# Epoch 32: Train MSE = 0.001323 | Val MSE = 0.000915
#   → New best model saved
# Epoch 33: Train MSE = 0.001286 | Val MSE = 0.000863
#   → New best model saved
# Epoch 34: Train MSE = 0.001265 | Val MSE = 0.001145
# Epoch 35: Train MSE = 0.001234 | Val MSE = 0.001256
# Epoch 36: Train MSE = 0.001224 | Val MSE = 0.000959
# Epoch 37: Train MSE = 0.001154 | Val MSE = 0.001073
# Epoch 38: Train MSE = 0.001173 | Val MSE = 0.000756
#   → New best model saved
# Epoch 39: Train MSE = 0.001154 | Val MSE = 0.002720
# Epoch 40: Train MSE = 0.001073 | Val MSE = 0.000818
# Epoch 41: Train MSE = 0.001067 | Val MSE = 0.003219
# Epoch 42: Train MSE = 0.001081 | Val MSE = 0.000906
# Epoch 43: Train MSE = 0.001080 | Val MSE = 0.000675
#   → New best model saved
# Epoch 44: Train MSE = 0.001001 | Val MSE = 0.001084
# Epoch 45: Train MSE = 0.001078 | Val MSE = 0.001016
# Epoch 46: Train MSE = 0.000954 | Val MSE = 0.000757
# Epoch 47: Train MSE = 0.000995 | Val MSE = 0.000821
# Epoch 48: Train MSE = 0.000921 | Val MSE = 0.000816
# Epoch 49: Train MSE = 0.000950 | Val MSE = 0.000659
#   → New best model saved
# Epoch 50: Train MSE = 0.000912 | Val MSE = 0.000659
#   → New best model saved
# Epoch 51: Train MSE = 0.000936 | Val MSE = 0.000908
# Epoch 52: Train MSE = 0.000919 | Val MSE = 0.000653
#   → New best model saved
# Epoch 53: Train MSE = 0.000915 | Val MSE = 0.000962
# Epoch 54: Train MSE = 0.000888 | Val MSE = 0.000577
#   → New best model saved
# Epoch 55: Train MSE = 0.000842 | Val MSE = 0.000574
#   → New best model saved
# Epoch 56: Train MSE = 0.000860 | Val MSE = 0.000991
# Epoch 57: Train MSE = 0.000822 | Val MSE = 0.000537
#   → New best model saved
# Epoch 58: Train MSE = 0.000851 | Val MSE = 0.000623
# Epoch 59: Train MSE = 0.000811 | Val MSE = 0.000547
# Epoch 60: Train MSE = 0.000806 | Val MSE = 0.000681
# Epoch 61: Train MSE = 0.000834 | Val MSE = 0.000584
# Epoch 62: Train MSE = 0.000788 | Val MSE = 0.001198
# Epoch 63: Train MSE = 0.000814 | Val MSE = 0.000601
# Epoch 64: Train MSE = 0.000800 | Val MSE = 0.000539
# Epoch 65: Train MSE = 0.000753 | Val MSE = 0.000604
# Epoch 66: Train MSE = 0.000771 | Val MSE = 0.000528
#   → New best model saved
# Epoch 67: Train MSE = 0.000750 | Val MSE = 0.000538
# Epoch 68: Train MSE = 0.000750 | Val MSE = 0.000554
# Epoch 69: Train MSE = 0.000734 | Val MSE = 0.000513
#   → New best model saved
# Epoch 70: Train MSE = 0.000757 | Val MSE = 0.000759
# Epoch 71: Train MSE = 0.000750 | Val MSE = 0.001648
# Epoch 72: Train MSE = 0.000749 | Val MSE = 0.000476
#   → New best model saved
# Epoch 73: Train MSE = 0.000706 | Val MSE = 0.000515
# Epoch 74: Train MSE = 0.000740 | Val MSE = 0.000741
# Epoch 75: Train MSE = 0.000719 | Val MSE = 0.000756
# Epoch 76: Train MSE = 0.000716 | Val MSE = 0.000691
# Epoch 77: Train MSE = 0.000704 | Val MSE = 0.000479
# Epoch 78: Train MSE = 0.000689 | Val MSE = 0.000485
# Epoch 79: Train MSE = 0.000743 | Val MSE = 0.000608
# Epoch 80: Train MSE = 0.000678 | Val MSE = 0.001616
# Epoch 81: Train MSE = 0.000694 | Val MSE = 0.000568
# Epoch 82: Train MSE = 0.000688 | Val MSE = 0.000463
#   → New best model saved
# Epoch 83: Train MSE = 0.000697 | Val MSE = 0.000819
# Epoch 84: Train MSE = 0.000674 | Val MSE = 0.000677
# Epoch 85: Train MSE = 0.000668 | Val MSE = 0.000568
# Epoch 86: Train MSE = 0.000693 | Val MSE = 0.000559
# Epoch 87: Train MSE = 0.000676 | Val MSE = 0.000872
# Epoch 88: Train MSE = 0.000673 | Val MSE = 0.000436
#   → New best model saved
# Epoch 89: Train MSE = 0.000643 | Val MSE = 0.000799
# Epoch 90: Train MSE = 0.000663 | Val MSE = 0.000448
# Epoch 91: Train MSE = 0.000659 | Val MSE = 0.000532
# Epoch 92: Train MSE = 0.000663 | Val MSE = 0.000589
# Epoch 93: Train MSE = 0.000647 | Val MSE = 0.000579
# Epoch 94: Train MSE = 0.000668 | Val MSE = 0.000428
#   → New best model saved
# Epoch 95: Train MSE = 0.000633 | Val MSE = 0.000475
# Epoch 96: Train MSE = 0.000649 | Val MSE = 0.000445
# Epoch 97: Train MSE = 0.000647 | Val MSE = 0.000825
# Epoch 98: Train MSE = 0.000632 | Val MSE = 0.000687
# Epoch 99: Train MSE = 0.000650 | Val MSE = 0.000473
# Epoch 100: Train MSE = 0.000634 | Val MSE = 0.000470
# Using device: cuda
# Epoch 01: Train MSE = 94.302245 | Val MSE = 8.055763
#   → New best model saved
# Epoch 02: Train MSE = 7.116775 | Val MSE = 6.437397
#   → New best model saved
# Epoch 03: Train MSE = 3.377906 | Val MSE = 1.221222
#   → New best model saved
# Epoch 04: Train MSE = 0.591362 | Val MSE = 0.293295
#   → New best model saved
# Epoch 05: Train MSE = 0.196639 | Val MSE = 0.134042
#   → New best model saved
# Epoch 06: Train MSE = 0.113396 | Val MSE = 0.088349
#   → New best model saved
# Epoch 07: Train MSE = 0.081733 | Val MSE = 0.073915
#   → New best model saved
# Epoch 08: Train MSE = 0.065765 | Val MSE = 0.056747
#   → New best model saved
# Epoch 09: Train MSE = 0.054550 | Val MSE = 0.046472
#   → New best model saved
# Epoch 10: Train MSE = 0.046800 | Val MSE = 0.038440
#   → New best model saved
# Epoch 11: Train MSE = 0.040146 | Val MSE = 0.031194
#   → New best model saved
# Epoch 12: Train MSE = 0.034723 | Val MSE = 0.035870
# Epoch 13: Train MSE = 0.031024 | Val MSE = 0.027978
#   → New best model saved
# Epoch 14: Train MSE = 0.026513 | Val MSE = 0.031929
# Epoch 15: Train MSE = 0.024812 | Val MSE = 0.019710
#   → New best model saved
# Epoch 16: Train MSE = 0.022271 | Val MSE = 0.017859
#   → New best model saved
# Epoch 17: Train MSE = 0.020510 | Val MSE = 0.060293
# Epoch 18: Train MSE = 0.019698 | Val MSE = 0.013200
#   → New best model saved
# Epoch 19: Train MSE = 0.017524 | Val MSE = 0.014289
# Epoch 20: Train MSE = 0.016265 | Val MSE = 0.018456
# Epoch 21: Train MSE = 0.015688 | Val MSE = 0.011212
#   → New best model saved
# Epoch 22: Train MSE = 0.014595 | Val MSE = 0.012611
# Epoch 23: Train MSE = 0.013891 | Val MSE = 0.008930
#   → New best model saved
# Epoch 24: Train MSE = 0.013803 | Val MSE = 0.009337
# Epoch 25: Train MSE = 0.012452 | Val MSE = 0.009240
# Epoch 26: Train MSE = 0.013328 | Val MSE = 0.007743
#   → New best model saved
# Epoch 27: Train MSE = 0.010803 | Val MSE = 0.008778
# Epoch 28: Train MSE = 0.011403 | Val MSE = 0.007828
# Epoch 29: Train MSE = 0.010968 | Val MSE = 0.011891
# Epoch 30: Train MSE = 0.010590 | Val MSE = 0.007305
#   → New best model saved
# Epoch 31: Train MSE = 0.010462 | Val MSE = 0.006448
#   → New best model saved
# Epoch 32: Train MSE = 0.010399 | Val MSE = 0.007875
# Epoch 33: Train MSE = 0.008980 | Val MSE = 0.011464
# Epoch 34: Train MSE = 0.009289 | Val MSE = 0.018996
# Epoch 35: Train MSE = 0.009294 | Val MSE = 0.007349
# Epoch 36: Train MSE = 0.008876 | Val MSE = 0.004904
#   → New best model saved
# Epoch 37: Train MSE = 0.008990 | Val MSE = 0.004721
#   → New best model saved
# Epoch 38: Train MSE = 0.008570 | Val MSE = 0.007349
# Epoch 39: Train MSE = 0.008315 | Val MSE = 0.004898
# Epoch 40: Train MSE = 0.008287 | Val MSE = 0.007159
# Epoch 41: Train MSE = 0.008211 | Val MSE = 0.006094
# Epoch 42: Train MSE = 0.007933 | Val MSE = 0.005689
# Epoch 43: Train MSE = 0.008026 | Val MSE = 0.004602
#   → New best model saved
# Epoch 44: Train MSE = 0.007492 | Val MSE = 0.006313
# Epoch 45: Train MSE = 0.007353 | Val MSE = 0.009588
# Epoch 46: Train MSE = 0.007308 | Val MSE = 0.006320
# Epoch 47: Train MSE = 0.007293 | Val MSE = 0.009384
# Epoch 48: Train MSE = 0.007025 | Val MSE = 0.005740
# Epoch 49: Train MSE = 0.007146 | Val MSE = 0.007865
# Epoch 50: Train MSE = 0.006961 | Val MSE = 0.014321
# Epoch 51: Train MSE = 0.006977 | Val MSE = 0.006861
# Epoch 52: Train MSE = 0.006604 | Val MSE = 0.004737
# Epoch 53: Train MSE = 0.006578 | Val MSE = 0.003832
#   → New best model saved
# Epoch 54: Train MSE = 0.006338 | Val MSE = 0.004719
# Epoch 55: Train MSE = 0.006735 | Val MSE = 0.003539
#   → New best model saved
# Epoch 56: Train MSE = 0.006254 | Val MSE = 0.004237
# Epoch 57: Train MSE = 0.006250 | Val MSE = 0.004457
# Epoch 58: Train MSE = 0.005985 | Val MSE = 0.003243
#   → New best model saved
# Epoch 59: Train MSE = 0.006115 | Val MSE = 0.010174
# Epoch 60: Train MSE = 0.005988 | Val MSE = 0.005550
# Epoch 61: Train MSE = 0.005921 | Val MSE = 0.005435
# Epoch 62: Train MSE = 0.006152 | Val MSE = 0.005502
# Epoch 63: Train MSE = 0.005801 | Val MSE = 0.002943
#   → New best model saved
# Epoch 64: Train MSE = 0.005622 | Val MSE = 0.003136
# Epoch 65: Train MSE = 0.006042 | Val MSE = 0.003130
# Epoch 66: Train MSE = 0.005358 | Val MSE = 0.005664
# Epoch 67: Train MSE = 0.005614 | Val MSE = 0.003084
# Epoch 68: Train MSE = 0.005499 | Val MSE = 0.002775
#   → New best model saved
# Epoch 69: Train MSE = 0.005468 | Val MSE = 0.003457
# Epoch 70: Train MSE = 0.005383 | Val MSE = 0.007947
# Epoch 71: Train MSE = 0.005356 | Val MSE = 0.004254
# Epoch 72: Train MSE = 0.005482 | Val MSE = 0.011747
# Epoch 73: Train MSE = 0.005141 | Val MSE = 0.002658
#   → New best model saved
# Epoch 74: Train MSE = 0.005297 | Val MSE = 0.003332
# Epoch 75: Train MSE = 0.005067 | Val MSE = 0.003006
# Epoch 76: Train MSE = 0.005382 | Val MSE = 0.003052
# Epoch 77: Train MSE = 0.004895 | Val MSE = 0.002637
#   → New best model saved
# Epoch 78: Train MSE = 0.004992 | Val MSE = 0.014899
# Epoch 79: Train MSE = 0.005041 | Val MSE = 0.003265
# Epoch 80: Train MSE = 0.005017 | Val MSE = 0.006272
# Epoch 81: Train MSE = 0.004878 | Val MSE = 0.004313
# Epoch 82: Train MSE = 0.004856 | Val MSE = 0.006408
# Epoch 83: Train MSE = 0.004929 | Val MSE = 0.004327
# Epoch 84: Train MSE = 0.004750 | Val MSE = 0.006125
# Epoch 85: Train MSE = 0.004814 | Val MSE = 0.007590
# Epoch 86: Train MSE = 0.004886 | Val MSE = 0.003600
# Epoch 87: Train MSE = 0.004795 | Val MSE = 0.002340
#   → New best model saved
# Epoch 88: Train MSE = 0.004557 | Val MSE = 0.002668
# Epoch 89: Train MSE = 0.004582 | Val MSE = 0.003012
# Epoch 90: Train MSE = 0.004748 | Val MSE = 0.008421
# Epoch 91: Train MSE = 0.004814 | Val MSE = 0.006110
# Epoch 92: Train MSE = 0.004550 | Val MSE = 0.002693
# Epoch 93: Train MSE = 0.004436 | Val MSE = 0.005458
# Epoch 94: Train MSE = 0.004420 | Val MSE = 0.004744
# Epoch 95: Train MSE = 0.004571 | Val MSE = 0.002178
#   → New best model saved
# Epoch 96: Train MSE = 0.004537 | Val MSE = 0.002525
# Epoch 97: Train MSE = 0.004357 | Val MSE = 0.002513
# Epoch 98: Train MSE = 0.004575 | Val MSE = 0.006803
# Epoch 99: Train MSE = 0.004319 | Val MSE = 0.003408
# Epoch 100: Train MSE = 0.004422 | Val MSE = 0.005330
# Using device: cuda
# Epoch 01: Train MSE = 85.088602 | Val MSE = 0.014817
#   → New best model saved
# Epoch 02: Train MSE = 0.011551 | Val MSE = 0.008676
#   → New best model saved
# Epoch 03: Train MSE = 0.006985 | Val MSE = 0.005776
#   → New best model saved
# Epoch 04: Train MSE = 0.005105 | Val MSE = 0.004536
#   → New best model saved
# Epoch 05: Train MSE = 0.004114 | Val MSE = 0.003728
#   → New best model saved
# Epoch 06: Train MSE = 0.003422 | Val MSE = 0.003141
#   → New best model saved
# Epoch 07: Train MSE = 0.002993 | Val MSE = 0.002747
#   → New best model saved
# Epoch 08: Train MSE = 0.002572 | Val MSE = 0.002297
#   → New best model saved
# Epoch 09: Train MSE = 0.002264 | Val MSE = 0.002895
# Epoch 10: Train MSE = 0.002018 | Val MSE = 0.001807
#   → New best model saved
# Epoch 11: Train MSE = 0.001836 | Val MSE = 0.001828
# Epoch 12: Train MSE = 0.001819 | Val MSE = 0.000783
#   → New best model saved
# Epoch 13: Train MSE = 0.001384 | Val MSE = 0.000869
# Epoch 14: Train MSE = 0.001346 | Val MSE = 0.000707
#   → New best model saved
# Epoch 15: Train MSE = 0.001257 | Val MSE = 0.000794
# Epoch 16: Train MSE = 0.001095 | Val MSE = 0.000503
#   → New best model saved
# Epoch 17: Train MSE = 0.001250 | Val MSE = 0.000177
#   → New best model saved
# Epoch 18: Train MSE = 0.000944 | Val MSE = 0.000372
# Epoch 19: Train MSE = 0.001127 | Val MSE = 0.000280
# Epoch 20: Train MSE = 0.000959 | Val MSE = 0.002984
# Epoch 21: Train MSE = 0.000868 | Val MSE = 0.000920
# Epoch 22: Train MSE = 0.000915 | Val MSE = 0.000466
# Epoch 23: Train MSE = 0.000869 | Val MSE = 0.000294
# Epoch 24: Train MSE = 0.000853 | Val MSE = 0.000083
#   → New best model saved
# Epoch 25: Train MSE = 0.000834 | Val MSE = 0.001057
# Epoch 26: Train MSE = 0.000780 | Val MSE = 0.000187
# Epoch 27: Train MSE = 0.000772 | Val MSE = 0.000108
# Epoch 28: Train MSE = 0.000775 | Val MSE = 0.000112
# Epoch 29: Train MSE = 0.000687 | Val MSE = 0.000059
#   → New best model saved
# Epoch 30: Train MSE = 0.000844 | Val MSE = 0.000056
#   → New best model saved
# Epoch 31: Train MSE = 0.000625 | Val MSE = 0.000169
# Epoch 32: Train MSE = 0.000629 | Val MSE = 0.000530
# Epoch 33: Train MSE = 0.000752 | Val MSE = 0.000039
#   → New best model saved
# Epoch 34: Train MSE = 0.000735 | Val MSE = 0.000247
# Epoch 35: Train MSE = 0.000537 | Val MSE = 0.000103
# Epoch 36: Train MSE = 0.000624 | Val MSE = 0.000057
# Epoch 37: Train MSE = 0.000489 | Val MSE = 0.001138
# Epoch 38: Train MSE = 0.000632 | Val MSE = 0.000104
# Epoch 39: Train MSE = 0.000567 | Val MSE = 0.000047
# Epoch 40: Train MSE = 0.000650 | Val MSE = 0.000048
# Epoch 41: Train MSE = 0.000532 | Val MSE = 0.001059
# Epoch 42: Train MSE = 0.000617 | Val MSE = 0.000297
# Epoch 43: Train MSE = 0.000642 | Val MSE = 0.003266
# Epoch 44: Train MSE = 0.000488 | Val MSE = 0.000049
# Epoch 45: Train MSE = 0.000587 | Val MSE = 0.000201
# Epoch 46: Train MSE = 0.000629 | Val MSE = 0.000106
# Epoch 47: Train MSE = 0.000517 | Val MSE = 0.001772
# Epoch 48: Train MSE = 0.000552 | Val MSE = 0.000121
# Epoch 49: Train MSE = 0.000598 | Val MSE = 0.000040
# Epoch 50: Train MSE = 0.000602 | Val MSE = 0.000033
#   → New best model saved
# Epoch 51: Train MSE = 0.000612 | Val MSE = 0.000053
# Epoch 52: Train MSE = 0.000465 | Val MSE = 0.000031
#   → New best model saved
# Epoch 53: Train MSE = 0.000624 | Val MSE = 0.000169
# Epoch 54: Train MSE = 0.000593 | Val MSE = 0.000942
# Epoch 55: Train MSE = 0.000495 | Val MSE = 0.000139
# Epoch 56: Train MSE = 0.000489 | Val MSE = 0.000337
# Epoch 57: Train MSE = 0.000587 | Val MSE = 0.000067
# Epoch 58: Train MSE = 0.000655 | Val MSE = 0.001360
# Epoch 59: Train MSE = 0.000510 | Val MSE = 0.000034
# Epoch 60: Train MSE = 0.000517 | Val MSE = 0.000030
#   → New best model saved
# Epoch 61: Train MSE = 0.000557 | Val MSE = 0.000039
# Epoch 62: Train MSE = 0.000711 | Val MSE = 0.000030
# Epoch 63: Train MSE = 0.000347 | Val MSE = 0.000040
# Epoch 64: Train MSE = 0.000704 | Val MSE = 0.000035
# Epoch 65: Train MSE = 0.000433 | Val MSE = 0.000034
# Epoch 66: Train MSE = 0.000671 | Val MSE = 0.000034
# Epoch 67: Train MSE = 0.000447 | Val MSE = 0.000036
# Epoch 68: Train MSE = 0.000578 | Val MSE = 0.000073
# Epoch 69: Train MSE = 0.000543 | Val MSE = 0.000213
# Epoch 70: Train MSE = 0.000498 | Val MSE = 0.000203
# Epoch 71: Train MSE = 0.000518 | Val MSE = 0.000047
# Epoch 72: Train MSE = 0.000504 | Val MSE = 0.000043
# Epoch 73: Train MSE = 0.000581 | Val MSE = 0.000128
# Epoch 74: Train MSE = 0.000539 | Val MSE = 0.000909
# Epoch 75: Train MSE = 0.000471 | Val MSE = 0.000036
# Epoch 76: Train MSE = 0.000536 | Val MSE = 0.000088
# Epoch 77: Train MSE = 0.000545 | Val MSE = 0.000068
# Epoch 78: Train MSE = 0.000656 | Val MSE = 0.000036
# Epoch 79: Train MSE = 0.000432 | Val MSE = 0.000036
# Epoch 80: Train MSE = 0.000615 | Val MSE = 0.000510
# Early stopping triggered
# Using device: cuda
# Epoch 01: Train MSE = 29.260300 | Val MSE = 0.224743
#   → New best model saved
# Epoch 02: Train MSE = 0.114689 | Val MSE = 0.067940
#   → New best model saved
# Epoch 03: Train MSE = 0.050521 | Val MSE = 0.035853
#   → New best model saved
# Epoch 04: Train MSE = 0.024563 | Val MSE = 0.015251
#   → New best model saved
# Epoch 05: Train MSE = 0.010513 | Val MSE = 0.007110
#   → New best model saved
# Epoch 06: Train MSE = 0.005346 | Val MSE = 0.004007
#   → New best model saved
# Epoch 07: Train MSE = 0.003215 | Val MSE = 0.002538
#   → New best model saved
# Epoch 08: Train MSE = 0.002063 | Val MSE = 0.001659
#   → New best model saved
# Epoch 09: Train MSE = 0.001436 | Val MSE = 0.001166
#   → New best model saved
# Epoch 10: Train MSE = 0.001137 | Val MSE = 0.000927
#   → New best model saved
# Epoch 11: Train MSE = 0.000964 | Val MSE = 0.003061
# Epoch 12: Train MSE = 0.000918 | Val MSE = 0.000781
#   → New best model saved
# Epoch 13: Train MSE = 0.000972 | Val MSE = 0.000563
#   → New best model saved
# Epoch 14: Train MSE = 0.000839 | Val MSE = 0.000467
#   → New best model saved
# Epoch 15: Train MSE = 0.000829 | Val MSE = 0.001227
# Epoch 16: Train MSE = 0.000758 | Val MSE = 0.001441
# Epoch 17: Train MSE = 0.000680 | Val MSE = 0.000286
#   → New best model saved
# Epoch 18: Train MSE = 0.000654 | Val MSE = 0.008605
# Epoch 19: Train MSE = 0.000714 | Val MSE = 0.000215
#   → New best model saved
# Epoch 20: Train MSE = 0.000688 | Val MSE = 0.000198
#   → New best model saved
# Epoch 21: Train MSE = 0.000483 | Val MSE = 0.000174
#   → New best model saved
# Epoch 22: Train MSE = 0.000584 | Val MSE = 0.000194
# Epoch 23: Train MSE = 0.000559 | Val MSE = 0.000259
# Epoch 24: Train MSE = 0.000542 | Val MSE = 0.000152
#   → New best model saved
# Epoch 25: Train MSE = 0.000496 | Val MSE = 0.000152
#   → New best model saved
# Epoch 26: Train MSE = 0.000549 | Val MSE = 0.000145
#   → New best model saved
# Epoch 27: Train MSE = 0.000753 | Val MSE = 0.000159
# Epoch 28: Train MSE = 0.000440 | Val MSE = 0.001616
# Epoch 29: Train MSE = 0.000500 | Val MSE = 0.000562
# Epoch 30: Train MSE = 0.000476 | Val MSE = 0.000234
# Epoch 31: Train MSE = 0.000563 | Val MSE = 0.000144
#   → New best model saved
# Epoch 32: Train MSE = 0.000450 | Val MSE = 0.000621
# Epoch 33: Train MSE = 0.000501 | Val MSE = 0.000177
# Epoch 34: Train MSE = 0.000541 | Val MSE = 0.000144
#   → New best model saved
# Epoch 35: Train MSE = 0.000443 | Val MSE = 0.000132
#   → New best model saved
# Epoch 36: Train MSE = 0.000432 | Val MSE = 0.000149
# Epoch 37: Train MSE = 0.000537 | Val MSE = 0.002004
# Epoch 38: Train MSE = 0.000441 | Val MSE = 0.000228
# Epoch 39: Train MSE = 0.000519 | Val MSE = 0.000122
#   → New best model saved
# Epoch 40: Train MSE = 0.000424 | Val MSE = 0.000162
# Epoch 41: Train MSE = 0.000464 | Val MSE = 0.000133
# Epoch 42: Train MSE = 0.000437 | Val MSE = 0.001944
# Epoch 43: Train MSE = 0.000506 | Val MSE = 0.000571
# Epoch 44: Train MSE = 0.000423 | Val MSE = 0.002257
# Epoch 45: Train MSE = 0.000451 | Val MSE = 0.000116
#   → New best model saved
# Epoch 46: Train MSE = 0.000411 | Val MSE = 0.000181
# Epoch 47: Train MSE = 0.000492 | Val MSE = 0.000160
# Epoch 48: Train MSE = 0.000388 | Val MSE = 0.000311
# Epoch 49: Train MSE = 0.000441 | Val MSE = 0.000298
# Epoch 50: Train MSE = 0.000478 | Val MSE = 0.000108
#   → New best model saved
# Epoch 51: Train MSE = 0.000440 | Val MSE = 0.000341
# Epoch 52: Train MSE = 0.000420 | Val MSE = 0.000098
#   → New best model saved
# Epoch 53: Train MSE = 0.000488 | Val MSE = 0.000103
# Epoch 54: Train MSE = 0.000323 | Val MSE = 0.000134
# Epoch 55: Train MSE = 0.000415 | Val MSE = 0.000100
# Epoch 56: Train MSE = 0.000429 | Val MSE = 0.000095
#   → New best model saved
# Epoch 57: Train MSE = 0.000364 | Val MSE = 0.000148
# Epoch 58: Train MSE = 0.000466 | Val MSE = 0.000086
#   → New best model saved
# Epoch 59: Train MSE = 0.000387 | Val MSE = 0.001091
# Epoch 60: Train MSE = 0.000368 | Val MSE = 0.000091
# Epoch 61: Train MSE = 0.000408 | Val MSE = 0.000155
# Epoch 62: Train MSE = 0.000491 | Val MSE = 0.000085
#   → New best model saved
# Epoch 63: Train MSE = 0.000434 | Val MSE = 0.000085
# Epoch 64: Train MSE = 0.000313 | Val MSE = 0.000120
# Epoch 65: Train MSE = 0.000447 | Val MSE = 0.000137
# Epoch 66: Train MSE = 0.000399 | Val MSE = 0.000088
# Epoch 67: Train MSE = 0.000337 | Val MSE = 0.000084
#   → New best model saved
# Epoch 68: Train MSE = 0.000364 | Val MSE = 0.001389
# Epoch 69: Train MSE = 0.000582 | Val MSE = 0.000081
#   → New best model saved
# Epoch 70: Train MSE = 0.000272 | Val MSE = 0.004690
# Epoch 71: Train MSE = 0.000468 | Val MSE = 0.000085
# Epoch 72: Train MSE = 0.000300 | Val MSE = 0.003326
# Epoch 73: Train MSE = 0.000379 | Val MSE = 0.000090
# Epoch 74: Train MSE = 0.000396 | Val MSE = 0.000090
# Epoch 75: Train MSE = 0.000544 | Val MSE = 0.000081
#   → New best model saved
# Epoch 76: Train MSE = 0.000233 | Val MSE = 0.001658
# Epoch 77: Train MSE = 0.000363 | Val MSE = 0.000089
# Epoch 78: Train MSE = 0.000537 | Val MSE = 0.000080
#   → New best model saved
# Epoch 79: Train MSE = 0.000233 | Val MSE = 0.000122
# Epoch 80: Train MSE = 0.000374 | Val MSE = 0.000144
# Epoch 81: Train MSE = 0.000429 | Val MSE = 0.001249
# Epoch 82: Train MSE = 0.000325 | Val MSE = 0.000087
# Epoch 83: Train MSE = 0.000373 | Val MSE = 0.000429
# Epoch 84: Train MSE = 0.000348 | Val MSE = 0.000087
# Epoch 85: Train MSE = 0.000425 | Val MSE = 0.000087
# Epoch 86: Train MSE = 0.000293 | Val MSE = 0.000207
# Epoch 87: Train MSE = 0.000591 | Val MSE = 0.000244
# Epoch 88: Train MSE = 0.000180 | Val MSE = 0.000078
#   → New best model saved
# Epoch 89: Train MSE = 0.000354 | Val MSE = 0.000100
# Epoch 90: Train MSE = 0.000332 | Val MSE = 0.000080
# Epoch 91: Train MSE = 0.000452 | Val MSE = 0.000105
# Epoch 92: Train MSE = 0.000278 | Val MSE = 0.000126
# Epoch 93: Train MSE = 0.000361 | Val MSE = 0.000189
# Epoch 94: Train MSE = 0.000332 | Val MSE = 0.000095
# Epoch 95: Train MSE = 0.000368 | Val MSE = 0.000131
# Epoch 96: Train MSE = 0.000418 | Val MSE = 0.000255
# Epoch 97: Train MSE = 0.000288 | Val MSE = 0.000077
#   → New best model saved
# Epoch 98: Train MSE = 0.000545 | Val MSE = 0.000156
# Epoch 99: Train MSE = 0.000226 | Val MSE = 0.000077
#   → New best model saved
# Epoch 100: Train MSE = 0.000312 | Val MSE = 0.001087
# Using device: cuda
# Epoch 01: Train MSE = 92.969350 | Val MSE = 2.370546
#   → New best model saved
# Epoch 02: Train MSE = 1.452551 | Val MSE = 0.839893
#   → New best model saved
# Epoch 03: Train MSE = 0.610683 | Val MSE = 0.458679
#   → New best model saved
# Epoch 04: Train MSE = 0.370803 | Val MSE = 0.289130
#   → New best model saved
# Epoch 05: Train MSE = 0.245541 | Val MSE = 0.197973
#   → New best model saved
# Epoch 06: Train MSE = 0.177314 | Val MSE = 0.170125
#   → New best model saved
# Epoch 07: Train MSE = 0.133920 | Val MSE = 0.115711
#   → New best model saved
# Epoch 08: Train MSE = 0.107116 | Val MSE = 0.094448
#   → New best model saved
# Epoch 09: Train MSE = 0.091711 | Val MSE = 0.081021
#   → New best model saved
# Epoch 10: Train MSE = 0.080080 | Val MSE = 0.074943
#   → New best model saved
# Epoch 11: Train MSE = 0.066737 | Val MSE = 0.060085
#   → New best model saved
# Epoch 12: Train MSE = 0.055362 | Val MSE = 0.047173
#   → New best model saved
# Epoch 13: Train MSE = 0.045723 | Val MSE = 0.035394
#   → New best model saved
# Epoch 14: Train MSE = 0.039621 | Val MSE = 0.032316
#   → New best model saved
# Epoch 15: Train MSE = 0.034474 | Val MSE = 0.036972
# Epoch 16: Train MSE = 0.030230 | Val MSE = 0.036236
# Epoch 17: Train MSE = 0.028160 | Val MSE = 0.024467
#   → New best model saved
# Epoch 18: Train MSE = 0.025605 | Val MSE = 0.026464
# Epoch 19: Train MSE = 0.024540 | Val MSE = 0.032069
# Epoch 20: Train MSE = 0.024189 | Val MSE = 0.015903
#   → New best model saved
# Epoch 21: Train MSE = 0.022594 | Val MSE = 0.019766
# Epoch 22: Train MSE = 0.021150 | Val MSE = 0.014850
#   → New best model saved
# Epoch 23: Train MSE = 0.021422 | Val MSE = 0.014637
#   → New best model saved
# Epoch 24: Train MSE = 0.020282 | Val MSE = 0.017463
# Epoch 25: Train MSE = 0.019149 | Val MSE = 0.015840
# Epoch 26: Train MSE = 0.018089 | Val MSE = 0.018468
# Epoch 27: Train MSE = 0.017819 | Val MSE = 0.014142
#   → New best model saved
# Epoch 28: Train MSE = 0.017323 | Val MSE = 0.025359
# Epoch 29: Train MSE = 0.016274 | Val MSE = 0.014267
# Epoch 30: Train MSE = 0.016341 | Val MSE = 0.010066
#   → New best model saved
# Epoch 31: Train MSE = 0.015597 | Val MSE = 0.009221
#   → New best model saved
# Epoch 32: Train MSE = 0.015450 | Val MSE = 0.009068
#   → New best model saved
# Epoch 33: Train MSE = 0.014544 | Val MSE = 0.009264
# Epoch 34: Train MSE = 0.015194 | Val MSE = 0.009859
# Epoch 35: Train MSE = 0.013965 | Val MSE = 0.011143
# Epoch 36: Train MSE = 0.014254 | Val MSE = 0.013712
# Epoch 37: Train MSE = 0.013639 | Val MSE = 0.008103
#   → New best model saved
# Epoch 38: Train MSE = 0.013342 | Val MSE = 0.011575
# Epoch 39: Train MSE = 0.013519 | Val MSE = 0.007569
#   → New best model saved
# Epoch 40: Train MSE = 0.013124 | Val MSE = 0.017251
# Epoch 41: Train MSE = 0.012600 | Val MSE = 0.011468
# Epoch 42: Train MSE = 0.012764 | Val MSE = 0.022123
# Epoch 43: Train MSE = 0.011832 | Val MSE = 0.008343
# Epoch 44: Train MSE = 0.012595 | Val MSE = 0.011647
# Epoch 45: Train MSE = 0.012542 | Val MSE = 0.042735
# Epoch 46: Train MSE = 0.010638 | Val MSE = 0.006719
#   → New best model saved
# Epoch 47: Train MSE = 0.011749 | Val MSE = 0.006838
# Epoch 48: Train MSE = 0.011651 | Val MSE = 0.007497
# Epoch 49: Train MSE = 0.011429 | Val MSE = 0.009009
# Epoch 50: Train MSE = 0.010878 | Val MSE = 0.007521
# Epoch 51: Train MSE = 0.010865 | Val MSE = 0.008098
# Epoch 52: Train MSE = 0.010970 | Val MSE = 0.005984
#   → New best model saved
# Epoch 53: Train MSE = 0.010485 | Val MSE = 0.023950
# Epoch 54: Train MSE = 0.009945 | Val MSE = 0.046044
# Epoch 55: Train MSE = 0.010138 | Val MSE = 0.008341
# Epoch 56: Train MSE = 0.010089 | Val MSE = 0.008833
# Epoch 57: Train MSE = 0.009863 | Val MSE = 0.014106
# Epoch 58: Train MSE = 0.009848 | Val MSE = 0.027260
# Epoch 59: Train MSE = 0.010108 | Val MSE = 0.005264
#   → New best model saved
# Epoch 60: Train MSE = 0.008935 | Val MSE = 0.008964
# Epoch 61: Train MSE = 0.009811 | Val MSE = 0.005623
# Epoch 62: Train MSE = 0.009749 | Val MSE = 0.004933
#   → New best model saved
# Epoch 63: Train MSE = 0.008466 | Val MSE = 0.015286
# Epoch 64: Train MSE = 0.008971 | Val MSE = 0.015833
# Epoch 65: Train MSE = 0.008974 | Val MSE = 0.004671
#   → New best model saved
# Epoch 66: Train MSE = 0.009107 | Val MSE = 0.004828
# Epoch 67: Train MSE = 0.008425 | Val MSE = 0.007117
# Epoch 68: Train MSE = 0.008590 | Val MSE = 0.004676
# Epoch 69: Train MSE = 0.008605 | Val MSE = 0.004667
#   → New best model saved
# Epoch 70: Train MSE = 0.008450 | Val MSE = 0.004382
#   → New best model saved
# Epoch 71: Train MSE = 0.008757 | Val MSE = 0.004316
#   → New best model saved
# Epoch 72: Train MSE = 0.008305 | Val MSE = 0.005689
# Epoch 73: Train MSE = 0.007675 | Val MSE = 0.007414
# Epoch 74: Train MSE = 0.007971 | Val MSE = 0.004503
# Epoch 75: Train MSE = 0.008071 | Val MSE = 0.008702
# Epoch 76: Train MSE = 0.007662 | Val MSE = 0.004229
#   → New best model saved
# Epoch 77: Train MSE = 0.007884 | Val MSE = 0.003858
#   → New best model saved
# Epoch 78: Train MSE = 0.007488 | Val MSE = 0.003963
# Epoch 79: Train MSE = 0.007346 | Val MSE = 0.010941
# Epoch 80: Train MSE = 0.007694 | Val MSE = 0.004019
# Epoch 81: Train MSE = 0.007443 | Val MSE = 0.006078
# Epoch 82: Train MSE = 0.006915 | Val MSE = 0.011980
# Epoch 83: Train MSE = 0.007343 | Val MSE = 0.006585
# Epoch 84: Train MSE = 0.007071 | Val MSE = 0.006517
# Epoch 85: Train MSE = 0.006778 | Val MSE = 0.008510
# Epoch 86: Train MSE = 0.007319 | Val MSE = 0.003442
#   → New best model saved
# Epoch 87: Train MSE = 0.007114 | Val MSE = 0.003587
# Epoch 88: Train MSE = 0.006748 | Val MSE = 0.004894
# Epoch 89: Train MSE = 0.006654 | Val MSE = 0.003400
#   → New best model saved
# Epoch 90: Train MSE = 0.006511 | Val MSE = 0.003436
# Epoch 91: Train MSE = 0.006454 | Val MSE = 0.005168
# Epoch 92: Train MSE = 0.006896 | Val MSE = 0.004594
# Epoch 93: Train MSE = 0.006321 | Val MSE = 0.003125
#   → New best model saved
# Epoch 94: Train MSE = 0.006805 | Val MSE = 0.003727
# Epoch 95: Train MSE = 0.006540 | Val MSE = 0.003097
#   → New best model saved
# Epoch 96: Train MSE = 0.006154 | Val MSE = 0.003121
# Epoch 97: Train MSE = 0.006635 | Val MSE = 0.003311
# Epoch 98: Train MSE = 0.006002 | Val MSE = 0.005298
# Epoch 99: Train MSE = 0.006016 | Val MSE = 0.003031
#   → New best model saved
# Epoch 100: Train MSE = 0.006229 | Val MSE = 0.005320
# Using device: cuda
# Epoch 01: Train MSE = 184.981623 | Val MSE = 0.028368
#   → New best model saved
# Epoch 02: Train MSE = 0.016722 | Val MSE = 0.008665
#   → New best model saved
# ...
#   → New best model saved
# Epoch 35: Train MSE = 0.014589 | Val MSE = 0.011312
#   → New best model saved
# Epoch 36: Train MSE = 0.013750 | Val MSE = 0.020844
# Epoch 37: Train MSE = 0.013971 | Val MSE = 0.013445
# Epoch 38: Train MSE = 0.013346 | Val MSE = 0.011301
#   → New best model saved
# Epoch 39: Train MSE = 0.013598 | Val MSE = 0.011018
#   → New best model saved
# Epoch 40: Train MSE = 0.013181 | Val MSE = 0.014411
# Epoch 41: Train MSE = 0.013074 | Val MSE = 0.016150
# Epoch 42: Train MSE = 0.013117 | Val MSE = 0.010103
#   → New best model saved
# Epoch 43: Train MSE = 0.012962 | Val MSE = 0.009897
#   → New best model saved
# Epoch 44: Train MSE = 0.012592 | Val MSE = 0.038128
# Epoch 45: Train MSE = 0.012255 | Val MSE = 0.011978
# Epoch 46: Train MSE = 0.012299 | Val MSE = 0.009441
#   → New best model saved
# Epoch 47: Train MSE = 0.012401 | Val MSE = 0.010847
# Epoch 48: Train MSE = 0.011420 | Val MSE = 0.009908
# Epoch 49: Train MSE = 0.011957 | Val MSE = 0.009787
# Epoch 50: Train MSE = 0.011640 | Val MSE = 0.009599
# Epoch 51: Train MSE = 0.011506 | Val MSE = 0.012592
# Epoch 52: Train MSE = 0.010979 | Val MSE = 0.008989
#   → New best model saved
# Epoch 53: Train MSE = 0.011442 | Val MSE = 0.008483
#   → New best model saved
# Epoch 54: Train MSE = 0.010707 | Val MSE = 0.008565
# Epoch 55: Train MSE = 0.011073 | Val MSE = 0.008426
#   → New best model saved
# Epoch 56: Train MSE = 0.010798 | Val MSE = 0.009291
# Epoch 57: Train MSE = 0.010650 | Val MSE = 0.008185
#   → New best model saved
# Epoch 58: Train MSE = 0.010524 | Val MSE = 0.009518
# Epoch 59: Train MSE = 0.010562 | Val MSE = 0.007999
#   → New best model saved
# Epoch 60: Train MSE = 0.010042 | Val MSE = 0.008604
# Epoch 61: Train MSE = 0.010391 | Val MSE = 0.007699
#   → New best model saved
# Epoch 62: Train MSE = 0.010302 | Val MSE = 0.008839
# Epoch 63: Train MSE = 0.009813 | Val MSE = 0.007986
# Epoch 64: Train MSE = 0.010007 | Val MSE = 0.007715
# Epoch 65: Train MSE = 0.009688 | Val MSE = 0.008649
# Epoch 66: Train MSE = 0.009733 | Val MSE = 0.007561
#   → New best model saved
# Epoch 67: Train MSE = 0.009662 | Val MSE = 0.062636
# Epoch 68: Train MSE = 0.009449 | Val MSE = 0.008458
# Epoch 69: Train MSE = 0.009796 | Val MSE = 0.007177
#   → New best model saved
# Epoch 70: Train MSE = 0.009252 | Val MSE = 0.007280
# Epoch 71: Train MSE = 0.009245 | Val MSE = 0.012782
# Epoch 72: Train MSE = 0.009152 | Val MSE = 0.007009
#   → New best model saved
# Epoch 73: Train MSE = 0.009196 | Val MSE = 0.007386
# Epoch 74: Train MSE = 0.009088 | Val MSE = 0.009883
# Epoch 75: Train MSE = 0.009161 | Val MSE = 0.010148
# Epoch 76: Train MSE = 0.008922 | Val MSE = 0.007232
# Epoch 77: Train MSE = 0.009164 | Val MSE = 0.006773
#   → New best model saved
# Epoch 78: Train MSE = 0.008679 | Val MSE = 0.012398
# Epoch 79: Train MSE = 0.008506 | Val MSE = 0.007056
# Epoch 80: Train MSE = 0.008733 | Val MSE = 0.006405
#   → New best model saved
# Epoch 81: Train MSE = 0.008583 | Val MSE = 0.006543
# Epoch 82: Train MSE = 0.008496 | Val MSE = 0.006148
#   → New best model saved
# Epoch 83: Train MSE = 0.008242 | Val MSE = 0.022427
# Epoch 84: Train MSE = 0.008546 | Val MSE = 0.006173
# Epoch 85: Train MSE = 0.008291 | Val MSE = 0.006389
# Epoch 86: Train MSE = 0.008007 | Val MSE = 0.007030
# Epoch 87: Train MSE = 0.008334 | Val MSE = 0.007037
# Epoch 88: Train MSE = 0.007900 | Val MSE = 0.006604
# Epoch 89: Train MSE = 0.008341 | Val MSE = 0.005944
#   → New best model saved
# Epoch 90: Train MSE = 0.008325 | Val MSE = 0.007263
# Epoch 91: Train MSE = 0.007622 | Val MSE = 0.009844
# Epoch 92: Train MSE = 0.007873 | Val MSE = 0.019455
# Epoch 93: Train MSE = 0.007989 | Val MSE = 0.007197
# Epoch 94: Train MSE = 0.007744 | Val MSE = 0.006298
# Epoch 95: Train MSE = 0.007990 | Val MSE = 0.006087
# Epoch 96: Train MSE = 0.008041 | Val MSE = 0.005904
#   → New best model saved
# Epoch 97: Train MSE = 0.007420 | Val MSE = 0.012608
# Epoch 98: Train MSE = 0.007739 | Val MSE = 0.006015
# Epoch 99: Train MSE = 0.007870 | Val MSE = 0.006623
# Epoch 100: Train MSE = 0.007481 | Val MSE = 0.006530
# Using device: cuda
# Epoch 01: Train MSE = 127.080011 | Val MSE = 0.554705
#   → New best model saved
# Epoch 02: Train MSE = 0.197508 | Val MSE = 0.111482
#   → New best model saved
# Epoch 03: Train MSE = 0.094509 | Val MSE = 0.078946
#   → New best model saved
# Epoch 04: Train MSE = 0.066059 | Val MSE = 0.054428
#   → New best model saved
# Epoch 05: Train MSE = 0.045681 | Val MSE = 0.038127
#   → New best model saved
# Epoch 06: Train MSE = 0.032742 | Val MSE = 0.028162
#   → New best model saved
# Epoch 07: Train MSE = 0.024775 | Val MSE = 0.021751
#   → New best model saved
# Epoch 08: Train MSE = 0.019292 | Val MSE = 0.016831
#   → New best model saved
# Epoch 09: Train MSE = 0.015251 | Val MSE = 0.013350
#   → New best model saved
# Epoch 10: Train MSE = 0.011862 | Val MSE = 0.009056
#   → New best model saved
# Epoch 11: Train MSE = 0.007192 | Val MSE = 0.006412
#   → New best model saved
# Epoch 12: Train MSE = 0.003954 | Val MSE = 0.005000
#   → New best model saved
# Epoch 13: Train MSE = 0.003125 | Val MSE = 0.001945
#   → New best model saved
# Epoch 14: Train MSE = 0.002417 | Val MSE = 0.001620
#   → New best model saved
# Epoch 15: Train MSE = 0.002406 | Val MSE = 0.001473
#   → New best model saved
# Epoch 16: Train MSE = 0.002205 | Val MSE = 0.001246
#   → New best model saved
# Epoch 17: Train MSE = 0.002173 | Val MSE = 0.001139
#   → New best model saved
# Epoch 18: Train MSE = 0.001894 | Val MSE = 0.001289
# Epoch 19: Train MSE = 0.002024 | Val MSE = 0.003079
# Epoch 20: Train MSE = 0.002001 | Val MSE = 0.000950
#   → New best model saved
# Epoch 21: Train MSE = 0.001778 | Val MSE = 0.006082
# Epoch 22: Train MSE = 0.001807 | Val MSE = 0.001311
# Epoch 23: Train MSE = 0.001767 | Val MSE = 0.001006
# Epoch 24: Train MSE = 0.001635 | Val MSE = 0.000633
#   → New best model saved
# Epoch 25: Train MSE = 0.001465 | Val MSE = 0.000679
# Epoch 26: Train MSE = 0.001469 | Val MSE = 0.001045
# Epoch 27: Train MSE = 0.001509 | Val MSE = 0.000539
#   → New best model saved
# Epoch 28: Train MSE = 0.001368 | Val MSE = 0.000653
# Epoch 29: Train MSE = 0.001424 | Val MSE = 0.005481
# Epoch 30: Train MSE = 0.001386 | Val MSE = 0.000559
# Epoch 31: Train MSE = 0.001337 | Val MSE = 0.000654
# Epoch 32: Train MSE = 0.001459 | Val MSE = 0.000896
# Epoch 33: Train MSE = 0.001240 | Val MSE = 0.005138
# Epoch 34: Train MSE = 0.001415 | Val MSE = 0.001413
# Epoch 35: Train MSE = 0.001257 | Val MSE = 0.000786
# Epoch 36: Train MSE = 0.001288 | Val MSE = 0.000969
# Epoch 37: Train MSE = 0.001322 | Val MSE = 0.000558
# Epoch 38: Train MSE = 0.001281 | Val MSE = 0.001912
# Epoch 39: Train MSE = 0.001392 | Val MSE = 0.004265
# Epoch 40: Train MSE = 0.001189 | Val MSE = 0.000452
#   → New best model saved
# Epoch 41: Train MSE = 0.001149 | Val MSE = 0.000480
# Epoch 42: Train MSE = 0.001327 | Val MSE = 0.000517
# Epoch 43: Train MSE = 0.001299 | Val MSE = 0.000645
# Epoch 44: Train MSE = 0.001387 | Val MSE = 0.000417
#   → New best model saved
# Epoch 45: Train MSE = 0.000985 | Val MSE = 0.000820
# Epoch 46: Train MSE = 0.001388 | Val MSE = 0.001815
# Epoch 47: Train MSE = 0.001100 | Val MSE = 0.000475
# Epoch 48: Train MSE = 0.001288 | Val MSE = 0.000926
# Epoch 49: Train MSE = 0.001161 | Val MSE = 0.000395
#   → New best model saved
# Epoch 50: Train MSE = 0.001145 | Val MSE = 0.000428
# Epoch 51: Train MSE = 0.001294 | Val MSE = 0.000405
# Epoch 52: Train MSE = 0.001117 | Val MSE = 0.000505
# Epoch 53: Train MSE = 0.001361 | Val MSE = 0.000386
#   → New best model saved
# Epoch 54: Train MSE = 0.001090 | Val MSE = 0.016300
# Epoch 55: Train MSE = 0.001334 | Val MSE = 0.000389
# Epoch 56: Train MSE = 0.001037 | Val MSE = 0.002963
# Epoch 57: Train MSE = 0.001272 | Val MSE = 0.000482
# Epoch 58: Train MSE = 0.001186 | Val MSE = 0.000825
# Epoch 59: Train MSE = 0.001076 | Val MSE = 0.008631
# Epoch 60: Train MSE = 0.001121 | Val MSE = 0.000856
# Epoch 61: Train MSE = 0.001239 | Val MSE = 0.000357
#   → New best model saved
# Epoch 62: Train MSE = 0.001068 | Val MSE = 0.000817
# Epoch 63: Train MSE = 0.001131 | Val MSE = 0.000443
# Epoch 64: Train MSE = 0.001093 | Val MSE = 0.004268
# Epoch 65: Train MSE = 0.001118 | Val MSE = 0.000346
#   → New best model saved
# Epoch 66: Train MSE = 0.001096 | Val MSE = 0.000981
# Epoch 67: Train MSE = 0.001171 | Val MSE = 0.000356
# Epoch 68: Train MSE = 0.001095 | Val MSE = 0.000417
# Epoch 69: Train MSE = 0.001337 | Val MSE = 0.000332
#   → New best model saved
# Epoch 70: Train MSE = 0.000857 | Val MSE = 0.003114
# Epoch 71: Train MSE = 0.001182 | Val MSE = 0.000337
# Epoch 72: Train MSE = 0.001127 | Val MSE = 0.000809
# Epoch 73: Train MSE = 0.000992 | Val MSE = 0.000427
# Epoch 74: Train MSE = 0.001093 | Val MSE = 0.000342
# Epoch 75: Train MSE = 0.001014 | Val MSE = 0.000495
# Epoch 76: Train MSE = 0.001156 | Val MSE = 0.000356
# Epoch 77: Train MSE = 0.001054 | Val MSE = 0.000336
# Epoch 78: Train MSE = 0.001051 | Val MSE = 0.000317
#   → New best model saved
# Epoch 79: Train MSE = 0.001171 | Val MSE = 0.000963
# Epoch 80: Train MSE = 0.000871 | Val MSE = 0.000828
# Epoch 81: Train MSE = 0.001157 | Val MSE = 0.000365
# Epoch 82: Train MSE = 0.001179 | Val MSE = 0.000309
#   → New best model saved
# Epoch 83: Train MSE = 0.000817 | Val MSE = 0.001520
# Epoch 84: Train MSE = 0.001063 | Val MSE = 0.000506
# Epoch 85: Train MSE = 0.001319 | Val MSE = 0.000308
#   → New best model saved
# Epoch 86: Train MSE = 0.001021 | Val MSE = 0.001190
# Epoch 87: Train MSE = 0.000922 | Val MSE = 0.000305
#   → New best model saved
# Epoch 88: Train MSE = 0.000950 | Val MSE = 0.000341
# Epoch 89: Train MSE = 0.000993 | Val MSE = 0.008696
# Epoch 90: Train MSE = 0.001037 | Val MSE = 0.000302
#   → New best model saved
# Epoch 91: Train MSE = 0.001099 | Val MSE = 0.000300
#   → New best model saved
# Epoch 92: Train MSE = 0.000902 | Val MSE = 0.000289
#   → New best model saved
# Epoch 93: Train MSE = 0.001044 | Val MSE = 0.001389
# Epoch 94: Train MSE = 0.000962 | Val MSE = 0.000320
# Epoch 95: Train MSE = 0.001016 | Val MSE = 0.000287
#   → New best model saved
# Epoch 96: Train MSE = 0.000989 | Val MSE = 0.000319
# Epoch 97: Train MSE = 0.001125 | Val MSE = 0.000293
# Epoch 98: Train MSE = 0.000785 | Val MSE = 0.000270
#   → New best model saved
# Epoch 99: Train MSE = 0.000996 | Val MSE = 0.000341
# Epoch 100: Train MSE = 0.001071 | Val MSE = 0.000472
# Using device: cuda
# Epoch 01: Train MSE = 27.731235 | Val MSE = 0.400164
#   → New best model saved
# Epoch 02: Train MSE = 0.188405 | Val MSE = 0.079037
#   → New best model saved
# Epoch 03: Train MSE = 0.048144 | Val MSE = 0.029658
#   → New best model saved
# Epoch 04: Train MSE = 0.021258 | Val MSE = 0.014545
#   → New best model saved
# Epoch 05: Train MSE = 0.010105 | Val MSE = 0.006526
#   → New best model saved
# Epoch 06: Train MSE = 0.004467 | Val MSE = 0.002959
#   → New best model saved
# Epoch 07: Train MSE = 0.002182 | Val MSE = 0.001599
#   → New best model saved
# Epoch 08: Train MSE = 0.001337 | Val MSE = 0.001048
#   → New best model saved
# Epoch 09: Train MSE = 0.000907 | Val MSE = 0.000770
#   → New best model saved
# Epoch 10: Train MSE = 0.000638 | Val MSE = 0.000491
#   → New best model saved
# Epoch 11: Train MSE = 0.000500 | Val MSE = 0.000595
# Epoch 12: Train MSE = 0.000471 | Val MSE = 0.005766
# Epoch 13: Train MSE = 0.000465 | Val MSE = 0.000269
#   → New best model saved
# Epoch 14: Train MSE = 0.000481 | Val MSE = 0.000274
# Epoch 15: Train MSE = 0.000464 | Val MSE = 0.001715
# Epoch 16: Train MSE = 0.000455 | Val MSE = 0.000399
# Epoch 17: Train MSE = 0.000477 | Val MSE = 0.000265
#   → New best model saved
# Epoch 18: Train MSE = 0.000476 | Val MSE = 0.000222
#   → New best model saved
# Epoch 19: Train MSE = 0.000421 | Val MSE = 0.002851
# Epoch 20: Train MSE = 0.000502 | Val MSE = 0.000172
#   → New best model saved
# Epoch 21: Train MSE = 0.000374 | Val MSE = 0.000178
# Epoch 22: Train MSE = 0.000407 | Val MSE = 0.000166
#   → New best model saved
# Epoch 23: Train MSE = 0.000419 | Val MSE = 0.000452
# Epoch 24: Train MSE = 0.000418 | Val MSE = 0.000163
#   → New best model saved
# Epoch 25: Train MSE = 0.000412 | Val MSE = 0.000191
# Epoch 26: Train MSE = 0.000411 | Val MSE = 0.000146
#   → New best model saved
# Epoch 27: Train MSE = 0.000393 | Val MSE = 0.000247
# Epoch 28: Train MSE = 0.000423 | Val MSE = 0.000141
#   → New best model saved
# Epoch 29: Train MSE = 0.000388 | Val MSE = 0.000153
# Epoch 30: Train MSE = 0.000403 | Val MSE = 0.000168
# Epoch 31: Train MSE = 0.000362 | Val MSE = 0.000489
# Epoch 32: Train MSE = 0.000462 | Val MSE = 0.005830
# Epoch 33: Train MSE = 0.000354 | Val MSE = 0.002114
# Epoch 34: Train MSE = 0.000312 | Val MSE = 0.000143
# Epoch 35: Train MSE = 0.000365 | Val MSE = 0.000152
# Epoch 36: Train MSE = 0.000379 | Val MSE = 0.000143
# Epoch 37: Train MSE = 0.000332 | Val MSE = 0.000120
#   → New best model saved
# Epoch 38: Train MSE = 0.000379 | Val MSE = 0.000127
# Epoch 39: Train MSE = 0.000333 | Val MSE = 0.000138
# Epoch 40: Train MSE = 0.000404 | Val MSE = 0.000561
# Epoch 41: Train MSE = 0.000339 | Val MSE = 0.000463
# Epoch 42: Train MSE = 0.000295 | Val MSE = 0.000140
# Epoch 43: Train MSE = 0.000380 | Val MSE = 0.000129
# Epoch 44: Train MSE = 0.000304 | Val MSE = 0.000114
#   → New best model saved
# Epoch 45: Train MSE = 0.000325 | Val MSE = 0.000230
# Epoch 46: Train MSE = 0.000345 | Val MSE = 0.000133
# Epoch 47: Train MSE = 0.000333 | Val MSE = 0.000140
# Epoch 48: Train MSE = 0.000355 | Val MSE = 0.000119
# Epoch 49: Train MSE = 0.000321 | Val MSE = 0.000115
# Epoch 50: Train MSE = 0.000326 | Val MSE = 0.000144
# Epoch 51: Train MSE = 0.000332 | Val MSE = 0.000626
# Epoch 52: Train MSE = 0.000348 | Val MSE = 0.000112
#   → New best model saved
# Epoch 53: Train MSE = 0.000275 | Val MSE = 0.000128
# Epoch 54: Train MSE = 0.000354 | Val MSE = 0.000109
#   → New best model saved
# Epoch 55: Train MSE = 0.000355 | Val MSE = 0.000132
# Epoch 56: Train MSE = 0.000320 | Val MSE = 0.000137
# Epoch 57: Train MSE = 0.000311 | Val MSE = 0.000133
# Epoch 58: Train MSE = 0.000282 | Val MSE = 0.000126
# Epoch 59: Train MSE = 0.000311 | Val MSE = 0.000109
# Epoch 60: Train MSE = 0.000299 | Val MSE = 0.001472
# Epoch 61: Train MSE = 0.000320 | Val MSE = 0.000376
# Epoch 62: Train MSE = 0.000300 | Val MSE = 0.000148
# Epoch 63: Train MSE = 0.000380 | Val MSE = 0.000111
# Epoch 64: Train MSE = 0.000256 | Val MSE = 0.000153
# Epoch 65: Train MSE = 0.000310 | Val MSE = 0.000156
# Epoch 66: Train MSE = 0.000315 | Val MSE = 0.000155
# Epoch 67: Train MSE = 0.000277 | Val MSE = 0.000108
#   → New best model saved
# Epoch 68: Train MSE = 0.000346 | Val MSE = 0.000347
# Epoch 69: Train MSE = 0.000271 | Val MSE = 0.007695
# Epoch 70: Train MSE = 0.000281 | Val MSE = 0.000115
# Epoch 71: Train MSE = 0.000303 | Val MSE = 0.000110
# Epoch 72: Train MSE = 0.000346 | Val MSE = 0.000121
# Epoch 73: Train MSE = 0.000236 | Val MSE = 0.000489
# Epoch 74: Train MSE = 0.000335 | Val MSE = 0.000184
# Epoch 75: Train MSE = 0.000265 | Val MSE = 0.000123
# Epoch 76: Train MSE = 0.000290 | Val MSE = 0.000106
#   → New best model saved
# Epoch 77: Train MSE = 0.000297 | Val MSE = 0.000129
# Epoch 78: Train MSE = 0.000307 | Val MSE = 0.000632
# Epoch 79: Train MSE = 0.000261 | Val MSE = 0.000111
# Epoch 80: Train MSE = 0.000303 | Val MSE = 0.000125
# Epoch 81: Train MSE = 0.000267 | Val MSE = 0.000459
# Epoch 82: Train MSE = 0.000343 | Val MSE = 0.000101
#   → New best model saved
# Epoch 83: Train MSE = 0.000224 | Val MSE = 0.000228
# Epoch 84: Train MSE = 0.000291 | Val MSE = 0.000105
# Epoch 85: Train MSE = 0.000268 | Val MSE = 0.000118
# Epoch 86: Train MSE = 0.000273 | Val MSE = 0.000120
# Epoch 87: Train MSE = 0.000260 | Val MSE = 0.000594
# Epoch 88: Train MSE = 0.000296 | Val MSE = 0.000121
# Epoch 89: Train MSE = 0.000268 | Val MSE = 0.000104
# Epoch 90: Train MSE = 0.000253 | Val MSE = 0.000113
# Epoch 91: Train MSE = 0.000291 | Val MSE = 0.000102
# Epoch 92: Train MSE = 0.000280 | Val MSE = 0.000944
# Epoch 93: Train MSE = 0.000248 | Val MSE = 0.000100
#   → New best model saved
# Epoch 94: Train MSE = 0.000324 | Val MSE = 0.000112
# Epoch 95: Train MSE = 0.000199 | Val MSE = 0.000124
# Epoch 96: Train MSE = 0.000294 | Val MSE = 0.000111
# Epoch 97: Train MSE = 0.000229 | Val MSE = 0.000298
# Epoch 98: Train MSE = 0.000264 | Val MSE = 0.000362
# Epoch 99: Train MSE = 0.000265 | Val MSE = 0.000112
# Epoch 100: Train MSE = 0.000242 | Val MSE = 0.000107

# %%
def encode(Y):
    latent_dims = {
        0: 1, 1: 1, 2: 1,
        3: 1, 4: 2, 5: 1,
        6: 1, 7: 2, 8: 1,
        9: 1, 10: 2, 11: 1,
        12: 1, 13: 1, 14: 2,
        15: 1, 16: 1,}
    
    Y_shape = Y.shape
    
    Y_enc = []
    for bone in range(17):
        latent_dim = latent_dims[bone]
        model = AutoEncoder(latent_dim=latent_dim).to('cuda')
        model.load_state_dict(torch.load(f'best_models_cuda/best_model_bone{bone}.pth'))
        
        to_encode = Y[..., 3*bone:3*(bone+1)].reshape(-1,3)
        to_encode_tensor = torch.tensor(
            to_encode,
            dtype=torch.float,
            device='cuda')
        encoded_tensor = model.encoder(to_encode_tensor)
        Y_enc.append(encoded_tensor.cpu().detach().numpy())

    Y_enc = np.hstack(Y_enc)
    Y_enc = Y_enc.reshape(*Y_shape[:-1], 21)
    
    return Y_enc

# %%
def decode(Y):
    latent_dims = {
        0: 1, 1: 1, 2: 1,
        3: 1, 4: 2, 5: 1,
        6: 1, 7: 2, 8: 1,
        9: 1, 10: 2, 11: 1,
        12: 1, 13: 1, 14: 2,
        15: 1, 16: 1,}
    
    Y_shape = Y.shape
    
    current = 0
    Y_dec = []
    for bone in range(17):
        latent_dim = latent_dims[bone]
        model = AutoEncoder(latent_dim=latent_dim).to('cuda')

        model.load_state_dict(torch.load(f'best_models_cuda/best_model_bone{bone}.pth'))

        to_decode = Y[..., current:current + latent_dim].reshape(-1, latent_dim)
        current += latent_dim

        to_decode_tensor = torch.tensor(
            to_decode,
            dtype=torch.float,
            device='cuda')
        decoded_tensor = model.decoder(to_decode_tensor)
        Y_dec.append(decoded_tensor.cpu().detach().numpy())
        
    Y_dec = np.hstack(Y_dec)
    Y_dec = Y_dec.reshape(*Y_shape[:-1], 51)

    return Y_dec

# %% [markdown]
# ## Prediction generation

# %%
from config.transformers import TimeDomainTransformer

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

from sklearn.kernel_ridge import KernelRidge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor

import pyriemann
import pyriemann.regression

from xgboost import XGBRegressor

baseline_kr = Pipeline(
    [
        ('feature_extraction', TimeDomainTransformer(sigma_mpr=0.3)),
        ('scaler', StandardScaler()),
        ('regressor', KernelRidge(
            alpha = 0.01,
            gamma = 0.01,
            kernel='laplacian'))
    ]
)

baseline_knn = Pipeline(
    [
        ('feature_extraction', TimeDomainTransformer(sigma_mpr=0.3)),
        ('scaler', StandardScaler()),
        ('regressor', KNeighborsRegressor(
            n_neighbors = 5))
    ]
)

baseline_rf = Pipeline(
    [
        ('feature_extraction', TimeDomainTransformer(sigma_mpr=0.3)),
        ('scaler', StandardScaler()),
        ('regressor', RandomForestRegressor(
            n_estimators = 50,
            max_depth = 10,
            random_state=42))
    ]
)

baseline_xgb = Pipeline(
    [
        ('feature_extraction', TimeDomainTransformer(sigma_mpr=0.3)),
        ('scaler', StandardScaler()),
        ('regressor', XGBRegressor())
    ]
)

riem_kr = Pipeline(
    [
        ('feature_extraction', pyriemann.estimation.Covariances()),
        ('transformation', pyriemann.tangentspace.TangentSpace(
            metric = 'riemann',
            tsupdate = True)),
        ('scaler', StandardScaler()),
        ('regressor', KernelRidge(
            alpha = 0.01,
            gamma = 0.01,
            kernel='laplacian'))
    ]
)

riem_knn = Pipeline(
    [
        ('feature_extraction', pyriemann.estimation.Covariances()),
        ('transformation', pyriemann.tangentspace.TangentSpace(
            metric = 'riemann',
            tsupdate = True)),
        ('scaler', StandardScaler()),
        ('regressor', KNeighborsRegressor(
            n_neighbors = 5))
    ]
)

riem_rf = Pipeline(
    [
        ('feature_extraction', pyriemann.estimation.Covariances()),
        ('transformation', pyriemann.tangentspace.TangentSpace(
            metric = 'riemann',
            tsupdate = True)),
        ('scaler', StandardScaler()),
        ('regressor', RandomForestRegressor(
            n_estimators = 50,
            max_depth = 10,
            random_state=42))
    ]
)

riem_xgb = Pipeline(
    [
        ('feature_extraction', pyriemann.estimation.Covariances()),
        ('transformation', pyriemann.tangentspace.TangentSpace(
            metric = 'riemann',
            tsupdate = True)),
        ('scaler', StandardScaler()),
        ('regressor', XGBRegressor())
    ]
)

# %%
model = StackingRegressor(
    estimators = [
        baseline_kr,
        baseline_knn,
        baseline_rf,
        # riem_kr,
        riem_knn,
        # riem_rf
    ],
    end_estimator = KNeighborsRegressor(
        n_neighbors=7,
        p=1
    ),
    n_internal_folds=5
)

PATH = r'C:\Users\gianm\Documents\Uni\Big Data\F422\project\data\\'

confirmation = input('Have you inserted the correct model name and the expected RMSE?')

model_name = 'prova_stacking'
expected_rmse = '1000'

step_prediction = 50 # step for prediction

# preparing the training data
tw_extractor = TimeWindowTransformer(size = 500, step = step_prediction)
label_extractor = LabelWindowExtractor(size = 500, step = step_prediction)

DATASET = 'guided'
X = np.load(PATH + f'{DATASET}/{DATASET}_dataset_X.npy')
Y = np.load(PATH + f'{DATASET}/{DATASET}_dataset_Y.npy')

DATASET = 'freemoves'
XX = np.load(PATH + f'{DATASET}/{DATASET}_dataset_X.npy')
YY = np.load(PATH + f'{DATASET}/{DATASET}_dataset_Y.npy')

XX = XX[..., -230000:]
YY = YY[..., -230000:]

X = np.vstack([X, XX])
Y = np.vstack([Y, YY])

X_windows = tw_extractor.transform(X)
Y_labels = label_extractor.transform(Y)

# # encoding
# print('Encoding...')
# Y_labels = encode(Y_labels)
# print('Encoded.')

# stacking the sessions 
X_train = X_windows.reshape(-1, *X_windows.shape[2:])
Y_train = Y_labels.reshape(-1, *Y_labels.shape[2:])

# # scaling the target
# targ_scal = StandardScaler()
# Y_train = targ_scal.fit_transform(Y_train)

# training
print('Training...')
model.fit(X_train, Y_train)
print('Trained.')

# # predicting
# DATASET = 'guided'
# X_test = np.load(PATH + f'{DATASET}/{DATASET}_testset_X.npy')
# X_test = X_test.reshape(-1, *X_windows.shape[2:])
# print('Predicting...')
# Y_pred = model.predict(X_test)
# print('Predicted.')

# # scaling back
# Y_pred = targ_scal.inverse_transform(Y_pred)

# # decoding
# print('Decoding...')
# Y_pred = decode(Y_pred)
# print('Decoded.')

# saving
file_name = 'guided_encoding_scaling_meta_50.npy'

np.save(file_name, Y_pred)

Y_pred_guided = np.load('guided_encoding_scaling_meta_50.npy')
Y_pred_freemoves = np.load('dann_steps_50_rmse_10.npy')

Y_pred = np.vstack([Y_pred_guided, Y_pred_freemoves])
Y_pred_df = pd.DataFrame(Y_pred)
Y_pred_df.to_csv('very_last_try.csv', index=False, header=False)

# %%
PATH = r'C:\Users\gianm\Documents\Uni\Big Data\F422\project\data\\'

model_name = 'prova_autoencoders_dann'
expected_rmse = '1000'

step_prediction = 50 # step for prediction

# preparing the training data
tw_extractor = TimeWindowTransformer(size = 500, step = step_prediction)
label_extractor = LabelWindowExtractor(size = 500, step = step_prediction)

DATASET = 'freemoves'

X = np.load(PATH + f'{DATASET}/{DATASET}_dataset_X.npy')
Y = np.load(PATH + f'{DATASET}/{DATASET}_dataset_Y.npy')

# DATASET = 'guided'

# X = np.load(PATH + f'{DATASET}/{DATASET}_dataset_X.npy')
# Y = np.load(PATH + f'{DATASET}/{DATASET}_dataset_Y.npy')

# DATASET = 'freemoves'

# XX = np.load(PATH + f'{DATASET}/{DATASET}_dataset_X.npy')
# YY = np.load(PATH + f'{DATASET}/{DATASET}_dataset_Y.npy')

# XX = XX[..., -230000:]
# YY = YY[..., -230000:]

# X = np.vstack([X, XX])
# Y = np.vstack([Y, YY])

X_windows = tw_extractor.transform(X)
Y_labels = label_extractor.transform(Y)
session_ids = np.concatenate([
    np.full(X_windows[i].shape[0], i) for i in range(len(X_windows))
])

# Instantiate DANNRegressor
dann = DANNModel(
    lambda_grl=1.0, 
    num_domains=5, 
    output_dim=21
)

# temp_dann = TemporalDANNModel(
#     lambda_grl=1.0,
#     num_domains=5,
#     output_dim=51,
#     in_channels=8 * (2 if hasattr(X_transformed, 'ndim') and X_transformed.ndim == 4 else 1), # Adjust in_channels based on potential DeltaFeatureTransformer output
#     mode=1  # Or your desired mode
# )

model = DANNRegressor(
    model=dann,
    dataset_class=DANNWindowTensor,
    gamma_entropy=0.1,
    learning_rate=0.001,
    batch_size=128,
    max_epochs=50,
    session_ids=session_ids
)

# encoding
Y_labels_enc = encode(Y_labels)

# stacking the sessions 
X_train = X_windows.reshape(-1, *X_windows.shape[2:])
Y_train = Y_labels_enc.reshape(-1, *Y_labels_enc.shape[2:])

# training
model.fit(X_train, Y_train)
# Out:
# Epoch 01 | Train RMSE: 32.2118 | Train NMSE: 4.8147
#            λ = 0.100
# Epoch 02 | Train RMSE: 24.1203 | Train NMSE: 2.6996
#            λ = 0.200
# Epoch 03 | Train RMSE: 17.2390 | Train NMSE: 1.3790
#            λ = 0.300
# Epoch 04 | Train RMSE: 13.2059 | Train NMSE: 0.8092
#            λ = 0.400
# Epoch 05 | Train RMSE: 11.5614 | Train NMSE: 0.6202
#            λ = 0.500
# Epoch 06 | Train RMSE: 10.7124 | Train NMSE: 0.5325
#            λ = 0.600
# Epoch 07 | Train RMSE: 10.4088 | Train NMSE: 0.5027
#            λ = 0.700
# Epoch 08 | Train RMSE: 10.2001 | Train NMSE: 0.4828
#            λ = 0.800
# Epoch 09 | Train RMSE: 10.0450 | Train NMSE: 0.4682
#            λ = 0.900
# Epoch 10 | Train RMSE: 9.9303 | Train NMSE: 0.4576
#            λ = 1.000
# Epoch 11 | Train RMSE: 9.7924 | Train NMSE: 0.4450
#            λ = 1.000
# Epoch 12 | Train RMSE: 9.6875 | Train NMSE: 0.4355
#            λ = 1.000
# Epoch 13 | Train RMSE: 9.5766 | Train NMSE: 0.4256
#            λ = 1.000
# Epoch 14 | Train RMSE: 9.5059 | Train NMSE: 0.4193
#            λ = 1.000
# Epoch 15 | Train RMSE: 9.3799 | Train NMSE: 0.4083
#            λ = 1.000
# Epoch 16 | Train RMSE: 9.3256 | Train NMSE: 0.4035
#            λ = 1.000
# Epoch 17 | Train RMSE: 9.2324 | Train NMSE: 0.3955
#            λ = 1.000
# Epoch 18 | Train RMSE: 9.1994 | Train NMSE: 0.3927
#            λ = 1.000
# Epoch 19 | Train RMSE: 9.0369 | Train NMSE: 0.3789
#            λ = 1.000
# Epoch 20 | Train RMSE: 9.0546 | Train NMSE: 0.3804
#            λ = 1.000
# Epoch 21 | Train RMSE: 8.9423 | Train NMSE: 0.3711
#            λ = 1.000
# Epoch 22 | Train RMSE: 8.8723 | Train NMSE: 0.3653
#            λ = 1.000
# Epoch 23 | Train RMSE: 8.7532 | Train NMSE: 0.3555
#            λ = 1.000
# Epoch 24 | Train RMSE: 8.7033 | Train NMSE: 0.3515
#            λ = 1.000
# Epoch 25 | Train RMSE: 8.7127 | Train NMSE: 0.3522
#            λ = 1.000
# Epoch 26 | Train RMSE: 8.6271 | Train NMSE: 0.3454
#            λ = 1.000
# Epoch 27 | Train RMSE: 8.6674 | Train NMSE: 0.3486
#            λ = 1.000
# Epoch 28 | Train RMSE: 8.5181 | Train NMSE: 0.3367
#            λ = 1.000
# Epoch 29 | Train RMSE: 8.5093 | Train NMSE: 0.3360
#            λ = 1.000
# Epoch 30 | Train RMSE: 8.4898 | Train NMSE: 0.3345
#            λ = 1.000
# Epoch 31 | Train RMSE: 8.4422 | Train NMSE: 0.3307
#            λ = 1.000
# Epoch 32 | Train RMSE: 8.3574 | Train NMSE: 0.3241
#            λ = 1.000
# Epoch 33 | Train RMSE: 8.3709 | Train NMSE: 0.3251
#            λ = 1.000
# Epoch 34 | Train RMSE: 8.3738 | Train NMSE: 0.3254
#            λ = 1.000
# Epoch 35 | Train RMSE: 8.3557 | Train NMSE: 0.3240
#            λ = 1.000
# Epoch 36 | Train RMSE: 8.3160 | Train NMSE: 0.3209
#            λ = 1.000
# Epoch 37 | Train RMSE: 8.2530 | Train NMSE: 0.3161
#            λ = 1.000
# Epoch 38 | Train RMSE: 8.2502 | Train NMSE: 0.3158
#            λ = 1.000
# Epoch 39 | Train RMSE: 8.2108 | Train NMSE: 0.3128
#            λ = 1.000
# Epoch 40 | Train RMSE: 8.1967 | Train NMSE: 0.3118
#            λ = 1.000
# Epoch 41 | Train RMSE: 8.1976 | Train NMSE: 0.3118
#            λ = 1.000
# Epoch 42 | Train RMSE: 8.1715 | Train NMSE: 0.3098
#            λ = 1.000
# Epoch 43 | Train RMSE: 8.0875 | Train NMSE: 0.3035
#            λ = 1.000
# Epoch 44 | Train RMSE: 8.0829 | Train NMSE: 0.3032
#            λ = 1.000
# Epoch 45 | Train RMSE: 8.0713 | Train NMSE: 0.3023
#            λ = 1.000
# Epoch 46 | Train RMSE: 8.0626 | Train NMSE: 0.3016
#            λ = 1.000
# Epoch 47 | Train RMSE: 8.0191 | Train NMSE: 0.2984
#            λ = 1.000
# Epoch 48 | Train RMSE: 7.9658 | Train NMSE: 0.2944
#            λ = 1.000
# Epoch 49 | Train RMSE: 8.0166 | Train NMSE: 0.2982
#            λ = 1.000
# Epoch 50 | Train RMSE: 7.9838 | Train NMSE: 0.2958
#            λ = 1.000
# DANNRegressor(dataset_class=<class 'config.dann.DANNWindowTensor'>,
#               gamma_entropy=0.1,
#               model=DANNModel(
#   (feature_extractor): ConvFeatureExtractor(
#     (net): Sequential(
#       (0): Conv1d(8, 128, kernel_size=(16,), stride=(1,), padding=(8,))
#       (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv1d(128, 16, kernel_size=...
#       (0): Linear(in_features=128, out_features=64, bias=True)
#       (1): ReLU()
#       (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): Dropout(p=0.2, inplace=False)
#       (4): Linear(in_features=64, out_features=32, bias=True)
#       (5): ReLU()
#       (6): Dropout(p=0.2, inplace=False)
#       (7): Linear(in_features=32, out_features=5, bias=True)
#     )
#   )
# ),
#               session_ids=array([0, 0, 0, ..., 4, 4, 4], shape=(26955,)))

# %%
# predicting
DATASET = 'freemoves'
X_test = np.load(PATH + f'{DATASET}/{DATASET}_testset_X.npy')
X_test = X_test.reshape(-1, *X_windows.shape[2:])
Y_pred_enc = model.predict(X_test)

# decoding
Y_pred_dec = decode(Y_pred_enc)

# saving
file_name = 'prova_encoded_decoded_dann_0.001.npy'

np.save(file_name, Y_pred_dec)
